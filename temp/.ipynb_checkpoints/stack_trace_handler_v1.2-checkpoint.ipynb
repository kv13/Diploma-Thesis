# %%
# stack trace handler manipulates stack traces.
# It cleans stack traces from unecessary informations
# and finds the sequence of files.
# Stores the information on the filenames_dict

# %%
import os
import re
import json
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_22065/2826817180.py in <module>
#       2 import re
#       3 import json
# ----> 4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#initialize the dictionary and the path to find the stack traces
dir_path       = '/home/kostas/Documents/thesis/data_1'
filenames_dict = {}
tags_list      = []

# %%
# remove text from the stack trace 
# and keep only the sequence of functions
# returns a list with the function calls
def clean_stack_trace(stack_trace):
    
    clean_stack_trace = []
    temp_stack = stack_trace.split(" at ")[1:]
    
    to_find = re.compile("[|,|<|>]|/|\|=")
    
    #find where each function ends and keep only the path
    for f in temp_stack:
        temp      = f.find(')')
        temp_file = f[0:temp]
        
        # check the punctuations in order to 
        # avoid anything else
        match_obj = to_find.search(temp_file)
        if match_obj == None:
            clean_stack_trace.append(find_filename(temp_file))
        
    return clean_stack_trace

# %%
# remove the name of the function and store only the file
# which contains the function.  
# This is done by tracking the full stop
def find_filename(value):
    filename = ""
    words    = value.split("(")
    if len(words)>=2:
        parts = words[0].split(".")
        filename = ".".join(parts[0:-1])
        
    return filename

# %%
# proceed for every file in the directory
stack_traces_counter = 0  
for fname in os.listdir(dir_path):
    with open(os.path.join(dir_path,fname)) as json_file:
        
        print("working on file",fname,"\n")
        
        #load data
        data = json.load(json_file)
        
        for counter,value in enumerate(data):
            dirty_stack_trace = value['stack_trace']
            
            if dirty_stack_trace != []:
                stack_traces_counter += 1
                temp_list=value['tags']
                for i in range(len(temp_list)):
                    temp_list[i] = temp_list[i].strip()
                tags_list.append(temp_list)
                
                print("working on stack trace on issue",counter+1,"\n")
                stack_trace = clean_stack_trace(dirty_stack_trace[0])
                
                for counter2,value2 in enumerate(stack_trace):
                    
                    filename = value2
                    
                    # in case filename is empty move on the next
                    if filename == "":
                        continue
                    
                    # if filename already in dict. just add the next
                    # file
                    if filename in filenames_dict:
                        
                        #find next file if exists
                        next_filename = ""
                        
                        if counter2+1<len(stack_trace):
                            next_filename = stack_trace[counter2+1]
                        
                        if next_filename != "":
                            exist_flag = False
                            
                            for count,i in enumerate(filenames_dict[filename]):
                                if next_filename == i["name"]:
                                    exist_flag = True
                                    location = "page"+fname[13:fname.find('.')]+"_issue"+str(counter+1)
                                    filenames_dict[filename][count]["occurance"] += 1
                                    if location not in filenames_dict[filename][count]["location"]:
                                        filenames_dict[filename][count]["location"].append(location)
                                    break
                                
                            if exist_flag == False:
                                location = "page"+fname[13:fname.find('.')]+"_issue"+str(counter+1)
                                filenames_dict[filename].append({"name":next_filename,"location":[location],"occurance":1})
                            
                    # if filename isnt in dict initialize it.
                    else:
                        
                        #find next file if exists
                        next_filename = ""
                        
                        if counter2+1<len(stack_trace):
                            next_filename = stack_trace[counter2+1]
                        
                        #store the filename in dict only if exists next file.
                        if next_filename != "":
                            location = "page"+fname[13:fname.find('.')]+"_issue"+str(counter+1)
                            filenames_dict[filename] = [{"name": next_filename,"location":[location],"occurance":1}]
# Out:
# working on file data_word_emb72.json
#
# working on stack trace on issue 24
#
# working on file data_word_emb143.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 6
#
# working on stack trace on issue 9
#
# working on stack trace on issue 11
#
# working on stack trace on issue 12
#
# working on stack trace on issue 13
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on file data_word_emb188.json
#
# working on file data_word_emb98.json
#
# working on stack trace on issue 23
#
# working on file data_word_emb239.json
#
# working on stack trace on issue 8
#
# working on stack trace on issue 20
#
# working on file data_word_emb108.json
#
# working on stack trace on issue 17
#
# working on file data_word_emb46.json
#
# working on file data_word_emb31.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 6
#
# working on file data_word_emb120.json
#
# working on stack trace on issue 5
#
# working on file data_word_emb32.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 8
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on file data_word_emb82.json
#
# working on file data_word_emb228.json
#
# working on stack trace on issue 1
#
# working on file data_word_emb100.json
#
# working on stack trace on issue 1
#
# working on file data_word_emb114.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 5
#
# working on file data_word_emb124.json
#
# working on stack trace on issue 16
#
# working on stack trace on issue 25
#
# working on file data_word_emb86.json
#
# working on file data_word_emb140.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 9
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on file data_word_emb94.json
#
# working on stack trace on issue 8
#
# working on file data_word_emb9.json
#
# working on stack trace on issue 18
#
# working on file data_word_emb180.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 6
#
# working on stack trace on issue 9
#
# working on stack trace on issue 11
#
# working on stack trace on issue 12
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on file data_word_emb13.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 3
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on file data_word_emb147.json
#
# working on stack trace on issue 18
#
# working on stack trace on issue 25
#
# working on file data_word_emb144.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 13
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on file data_word_emb81.json
#
# working on stack trace on issue 2
#
# working on file data_word_emb220.json
#
# working on file data_word_emb24.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 5
#
# working on stack trace on issue 17
#
# working on file data_word_emb56.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 21
#
# working on file data_word_emb5.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 2
#
# working on stack trace on issue 9
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on file data_word_emb237.json
#
# working on file data_word_emb221.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 12
#
# working on file data_word_emb236.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 14
#
# working on stack trace on issue 22
#
# working on file data_word_emb133.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 14
#
# working on file data_word_emb91.json
#
# working on file data_word_emb47.json
#
# working on stack trace on issue 22
#
# working on file data_word_emb43.json
#
# working on stack trace on issue 6
#
# working on stack trace on issue 16
#
# working on stack trace on issue 25
#
# working on file data_word_emb49.json
#
# working on file data_word_emb182.json
#
# working on file data_word_emb160.json
#
# working on file data_word_emb37.json
#
# working on stack trace on issue 5
#
# working on file data_word_emb197.json
#
# working on stack trace on issue 8
#
# working on stack trace on issue 9
#
# working on file data_word_emb215.json
#
# working on stack trace on issue 20
#
# working on file data_word_emb40.json
#
# working on file data_word_emb61.json
#
# working on stack trace on issue 11
#
# working on file data_word_emb119.json
#
# working on file data_word_emb85.json
#
# working on stack trace on issue 4
#
# working on file data_word_emb178.json
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on stack trace on issue 19
#
# working on stack trace on issue 23
#
# working on file data_word_emb36.json
#
# working on stack trace on issue 13
#
# working on stack trace on issue 16
#
# working on file data_word_emb242.json
#
# working on file data_word_emb187.json
#
# working on stack trace on issue 15
#
# working on file data_word_emb205.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 12
#
# working on stack trace on issue 13
#
# working on stack trace on issue 20
#
# working on stack trace on issue 24
#
# working on file data_word_emb142.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 3
#
# working on stack trace on issue 4
#
# working on stack trace on issue 5
#
# working on stack trace on issue 21
#
# working on stack trace on issue 24
#
# working on file data_word_emb240.json
#
# working on stack trace on issue 18
#
# working on file data_word_emb23.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 18
#
# working on file data_word_emb174.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 6
#
# working on stack trace on issue 17
#
# working on stack trace on issue 21
#
# working on stack trace on issue 22
#
# working on file data_word_emb8.json
#
# working on stack trace on issue 6
#
# working on stack trace on issue 12
#
# working on stack trace on issue 17
#
# working on file data_word_emb16.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 24
#
# working on file data_word_emb175.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 11
#
# working on stack trace on issue 17
#
# working on file data_word_emb44.json
#
# working on stack trace on issue 8
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on file data_word_emb139.json
#
# working on file data_word_emb7.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 11
#
# working on stack trace on issue 15
#
# working on stack trace on issue 18
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on file data_word_emb208.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on file data_word_emb186.json
#
# working on stack trace on issue 20
#
# working on stack trace on issue 23
#
# working on file data_word_emb202.json
#
# working on stack trace on issue 17
#
# working on file data_word_emb97.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 3
#
# working on stack trace on issue 4
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on file data_word_emb78.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 17
#
# working on stack trace on issue 21
#
# working on stack trace on issue 24
#
# working on file data_word_emb111.json
#
# working on file data_word_emb123.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 2
#
# working on stack trace on issue 3
#
# working on stack trace on issue 4
#
# working on stack trace on issue 7
#
# working on stack trace on issue 10
#
# working on stack trace on issue 15
#
# working on file data_word_emb39.json
#
# working on stack trace on issue 1
#
# working on file data_word_emb62.json
#
# working on stack trace on issue 12
#
# working on file data_word_emb51.json
#
# working on file data_word_emb102.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on stack trace on issue 11
#
# working on stack trace on issue 22
#
# working on stack trace on issue 25
#
# working on file data_word_emb224.json
#
# working on stack trace on issue 14
#
# working on file data_word_emb17.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 14
#
# working on stack trace on issue 19
#
# working on stack trace on issue 23
#
# working on file data_word_emb230.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 25
#
# working on file data_word_emb179.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 6
#
# working on stack trace on issue 20
#
# working on file data_word_emb223.json
#
# working on stack trace on issue 8
#
# working on file data_word_emb4.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 8
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on stack trace on issue 23
#
# working on stack trace on issue 25
#
# working on file data_word_emb69.json
#
# working on stack trace on issue 13
#
# working on file data_word_emb76.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 20
#
# working on stack trace on issue 23
#
# working on file data_word_emb67.json
#
# working on stack trace on issue 17
#
# working on stack trace on issue 23
#
# working on file data_word_emb115.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 6
#
# working on stack trace on issue 12
#
# working on stack trace on issue 21
#
# working on stack trace on issue 24
#
# working on file data_word_emb104.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 11
#
# working on stack trace on issue 25
#
# working on file data_word_emb95.json
#
# working on stack trace on issue 22
#
# working on file data_word_emb161.json
#
# working on file data_word_emb22.json
#
# working on stack trace on issue 6
#
# working on stack trace on issue 9
#
# working on file data_word_emb34.json
#
# working on stack trace on issue 13
#
# working on file data_word_emb211.json
#
# working on stack trace on issue 21
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on file data_word_emb227.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 14
#
# working on stack trace on issue 21
#
# working on file data_word_emb165.json
#
# working on stack trace on issue 13
#
# working on stack trace on issue 18
#
# working on file data_word_emb129.json
#
# working on stack trace on issue 19
#
# working on file data_word_emb226.json
#
# working on stack trace on issue 3
#
# working on file data_word_emb238.json
#
# working on file data_word_emb172.json
#
# working on stack trace on issue 8
#
# working on stack trace on issue 11
#
# working on stack trace on issue 12
#
# working on file data_word_emb99.json
#
# working on stack trace on issue 12
#
# working on stack trace on issue 13
#
# working on file data_word_emb128.json
#
# working on stack trace on issue 23
#
# working on file data_word_emb194.json
#
# working on stack trace on issue 11
#
# working on file data_word_emb216.json
#
# working on stack trace on issue 20
#
# working on stack trace on issue 21
#
# working on file data_word_emb65.json
#
# working on stack trace on issue 3
#
# working on file data_word_emb96.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 11
#
# working on stack trace on issue 14
#
# working on stack trace on issue 20
#
# working on file data_word_emb199.json
#
# working on stack trace on issue 18
#
# working on file data_word_emb126.json
#
# working on file data_word_emb206.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 24
#
# working on file data_word_emb26.json
#
# working on stack trace on issue 23
#
# working on file data_word_emb152.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 4
#
# working on stack trace on issue 16
#
# working on file data_word_emb74.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 7
#
# working on stack trace on issue 23
#
# working on file data_word_emb58.json
#
# working on file data_word_emb38.json
#
# working on stack trace on issue 8
#
# working on file data_word_emb201.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 10
#
# working on stack trace on issue 21
#
# working on file data_word_emb3.json
#
# working on stack trace on issue 6
#
# working on stack trace on issue 9
#
# working on stack trace on issue 18
#
# working on file data_word_emb2.json
#
# working on stack trace on issue 9
#
# working on file data_word_emb141.json
#
# working on stack trace on issue 16
#
# working on file data_word_emb18.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 4
#
# working on stack trace on issue 5
#
# working on stack trace on issue 19
#
# working on file data_word_emb158.json
#
# working on stack trace on issue 2
#
# working on file data_word_emb11.json
#
# working on stack trace on issue 13
#
# working on stack trace on issue 17
#
# working on file data_word_emb125.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 16
#
# working on file data_word_emb213.json
#
# working on file data_word_emb59.json
#
# working on stack trace on issue 19
#
# working on file data_word_emb218.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 17
#
# working on stack trace on issue 21
#
# working on file data_word_emb1.json
#
# working on stack trace on issue 15
#
# working on stack trace on issue 16
#
# working on file data_word_emb84.json
#
# working on stack trace on issue 19
#
# working on file data_word_emb195.json
#
# working on stack trace on issue 21
#
# working on stack trace on issue 24
#
# working on file data_word_emb217.json
#
# working on stack trace on issue 12
#
# working on stack trace on issue 21
#
# working on file data_word_emb192.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 12
#
# working on stack trace on issue 20
#
# working on file data_word_emb27.json
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on stack trace on issue 24
#
# working on file data_word_emb19.json
#
# working on stack trace on issue 17
#
# working on file data_word_emb219.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 22
#
# working on file data_word_emb52.json
#
# working on file data_word_emb163.json
#
# working on stack trace on issue 20
#
# working on file data_word_emb225.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on file data_word_emb169.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 8
#
# working on stack trace on issue 19
#
# working on file data_word_emb66.json
#
# working on stack trace on issue 21
#
# working on stack trace on issue 22
#
# working on file data_word_emb185.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 7
#
# working on file data_word_emb243.json
#
# working on stack trace on issue 17
#
# working on file data_word_emb93.json
#
# working on file data_word_emb157.json
#
# working on file data_word_emb210.json
#
# working on stack trace on issue 25
#
# working on file data_word_emb138.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 4
#
# working on stack trace on issue 5
#
# working on stack trace on issue 6
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on stack trace on issue 20
#
# working on file data_word_emb71.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 9
#
# working on stack trace on issue 14
#
# working on file data_word_emb54.json
#
# working on stack trace on issue 21
#
# working on file data_word_emb41.json
#
# working on stack trace on issue 8
#
# working on stack trace on issue 15
#
# working on stack trace on issue 18
#
# working on stack trace on issue 22
#
# working on file data_word_emb20.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 12
#
# working on file data_word_emb14.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 18
#
# working on stack trace on issue 21
#
# working on file data_word_emb60.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on stack trace on issue 20
#
# working on stack trace on issue 21
#
# working on file data_word_emb134.json
#
# working on stack trace on issue 13
#
# working on stack trace on issue 23
#
# working on file data_word_emb88.json
#
# working on file data_word_emb189.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 8
#
# working on stack trace on issue 21
#
# working on file data_word_emb64.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 12
#
# working on stack trace on issue 24
#
# working on file data_word_emb35.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 6
#
# working on stack trace on issue 8
#
# working on stack trace on issue 9
#
# working on stack trace on issue 20
#
# working on file data_word_emb79.json
#
# working on stack trace on issue 5
#
# working on stack trace on issue 18
#
# working on file data_word_emb168.json
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on stack trace on issue 21
#
# working on file data_word_emb171.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 5
#
# working on stack trace on issue 7
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on file data_word_emb105.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 14
#
# working on stack trace on issue 25
#
# working on file data_word_emb113.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 13
#
# working on stack trace on issue 15
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on stack trace on issue 20
#
# working on stack trace on issue 25
#
# working on file data_word_emb28.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 20
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on stack trace on issue 24
#
# working on file data_word_emb234.json
#
# working on stack trace on issue 19
#
# working on file data_word_emb177.json
#
# working on stack trace on issue 15
#
# working on stack trace on issue 19
#
# working on file data_word_emb117.json
#
# working on file data_word_emb149.json
#
# working on file data_word_emb116.json
#
# working on stack trace on issue 6
#
# working on stack trace on issue 23
#
# working on file data_word_emb184.json
#
# working on stack trace on issue 12
#
# working on stack trace on issue 21
#
# working on file data_word_emb181.json
#
# working on stack trace on issue 1
#
# working on file data_word_emb103.json
#
# working on stack trace on issue 16
#
# working on stack trace on issue 22
#
# working on file data_word_emb229.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 19
#
# working on file data_word_emb70.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 9
#
# working on stack trace on issue 15
#
# working on stack trace on issue 24
#
# working on file data_word_emb73.json
#
# working on file data_word_emb146.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 12
#
# working on file data_word_emb50.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on stack trace on issue 11
#
# working on file data_word_emb131.json
#
# working on file data_word_emb106.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 18
#
# working on stack trace on issue 19
#
# working on file data_word_emb118.json
#
# working on file data_word_emb127.json
#
# working on stack trace on issue 8
#
# working on stack trace on issue 11
#
# working on stack trace on issue 12
#
# working on stack trace on issue 20
#
# working on file data_word_emb170.json
#
# working on stack trace on issue 21
#
# working on file data_word_emb162.json
#
# working on file data_word_emb48.json
#
# working on stack trace on issue 2
#
# working on file data_word_emb109.json
#
# working on stack trace on issue 18
#
# working on stack trace on issue 25
#
# working on file data_word_emb196.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on stack trace on issue 11
#
# working on stack trace on issue 22
#
# working on file data_word_emb151.json
#
# working on file data_word_emb198.json
#
# working on stack trace on issue 6
#
# working on file data_word_emb121.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 4
#
# working on stack trace on issue 12
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on stack trace on issue 18
#
# working on file data_word_emb214.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 12
#
# working on file data_word_emb204.json
#
# working on stack trace on issue 19
#
# working on stack trace on issue 20
#
# working on file data_word_emb33.json
#
# working on file data_word_emb12.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 24
#
# working on file data_word_emb75.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 17
#
# working on stack trace on issue 19
#
# working on stack trace on issue 20
#
# working on stack trace on issue 21
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on stack trace on issue 24
#
# working on stack trace on issue 25
#
# working on file data_word_emb83.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 25
#
# working on file data_word_emb207.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 10
#
# working on file data_word_emb233.json
#
# working on file data_word_emb200.json
#
# working on stack trace on issue 16
#
# working on stack trace on issue 18
#
# working on file data_word_emb80.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 14
#
# working on file data_word_emb191.json
# working on stack trace on issue 20
#
# working on stack trace on issue 25
#
# working on file data_word_emb30.json
#
# working on stack trace on issue 9
#
# working on file data_word_emb135.json
#
# working on stack trace on issue 25
#
# working on file data_word_emb148.json
#
# working on stack trace on issue 11
#
# working on file data_word_emb63.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on stack trace on issue 20
#
# working on stack trace on issue 21
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on file data_word_emb25.json
#
# working on stack trace on issue 20
#
# working on stack trace on issue 24
#
# working on file data_word_emb92.json
#
# working on stack trace on issue 12
#
# working on stack trace on issue 13
#
# working on stack trace on issue 16
#
# working on stack trace on issue 22
#
# working on file data_word_emb110.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 8
#
# working on stack trace on issue 9
#
# working on stack trace on issue 14
#
# working on stack trace on issue 19
#
# working on file data_word_emb235.json
#
# working on file data_word_emb193.json
#
# working on file data_word_emb10.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 20
#
# working on stack trace on issue 22
#
# working on file data_word_emb222.json
#
# working on file data_word_emb145.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on stack trace on issue 11
#
# working on stack trace on issue 17
#
# working on stack trace on issue 25
#
# working on file data_word_emb150.json
#
# working on file data_word_emb6.json
#
# working on stack trace on issue 6
#
# working on stack trace on issue 10
#
# working on stack trace on issue 13
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on file data_word_emb155.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 6
#
# working on stack trace on issue 7
#
# working on stack trace on issue 8
#
# working on stack trace on issue 9
#
# working on file data_word_emb87.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 8
#
# working on stack trace on issue 15
#
# working on stack trace on issue 16
#
# working on stack trace on issue 20
#
# working on file data_word_emb164.json
#
# working on stack trace on issue 13
#
# working on file data_word_emb112.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 13
#
# working on stack trace on issue 14
#
# working on file data_word_emb68.json
#
# working on stack trace on issue 4
#
# working on stack trace on issue 5
#
# working on stack trace on issue 23
#
# working on stack trace on issue 24
#
# working on file data_word_emb153.json
#
# working on file data_word_emb203.json
#
# working on file data_word_emb53.json
#
# working on file data_word_emb136.json
#
# working on stack trace on issue 12
#
# working on stack trace on issue 14
#
# working on stack trace on issue 16
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on file data_word_emb166.json
#
# working on stack trace on issue 11
#
# working on file data_word_emb90.json
#
# working on stack trace on issue 10
#
# working on file data_word_emb232.json
#
# working on stack trace on issue 11
#
# working on stack trace on issue 15
#
# working on file data_word_emb77.json
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on stack trace on issue 20
#
# working on file data_word_emb183.json
#
# working on stack trace on issue 12
#
# working on file data_word_emb15.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 21
#
# working on file data_word_emb154.json
#
# working on stack trace on issue 12
#
# working on stack trace on issue 23
#
# working on stack trace on issue 25
#
# working on file data_word_emb159.json
#
# working on file data_word_emb45.json
#
# working on file data_word_emb209.json
#
# working on stack trace on issue 14
#
# working on stack trace on issue 15
#
# working on stack trace on issue 18
#
# working on file data_word_emb167.json
#
# working on stack trace on issue 25
#
# working on file data_word_emb21.json
#
# working on file data_word_emb176.json
#
# working on stack trace on issue 9
#
# working on stack trace on issue 10
#
# working on file data_word_emb241.json
#
# working on file data_word_emb55.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 18
#
# working on file data_word_emb190.json
#
# working on file data_word_emb29.json
#
# working on stack trace on issue 2
#
# working on stack trace on issue 14
#
# working on stack trace on issue 19
#
# working on stack trace on issue 23
#
# working on file data_word_emb137.json
#
# working on stack trace on issue 13
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on stack trace on issue 24
#
# working on file data_word_emb42.json
#
# working on stack trace on issue 3
#
# working on stack trace on issue 4
#
# working on file data_word_emb231.json
#
# working on stack trace on issue 1
#
# working on stack trace on issue 8
#
# working on stack trace on issue 14
#
# working on stack trace on issue 17
#
# working on stack trace on issue 18
#
# working on file data_word_emb57.json
#
# working on stack trace on issue 11
#
# working on stack trace on issue 23
#
# working on file data_word_emb107.json
#
# working on stack trace on issue 20
#
# working on file data_word_emb212.json
#
# working on stack trace on issue 24
#
# working on file data_word_emb132.json
#
# working on file data_word_emb130.json
#
# working on stack trace on issue 10
#
# working on stack trace on issue 14
#
# working on file data_word_emb156.json
#
# working on stack trace on issue 20
#
# working on file data_word_emb173.json
#
# working on stack trace on issue 21
#
# working on stack trace on issue 23
#
# working on file data_word_emb89.json
#
# working on stack trace on issue 6
#
# working on file data_word_emb101.json
#
# working on stack trace on issue 14
#
# working on stack trace on issue 20
#
# working on stack trace on issue 21
#
# working on file data_word_emb122.json
#
# working on stack trace on issue 7
#
# working on stack trace on issue 15
#
# working on stack trace on issue 20
#
# working on stack trace on issue 22
#
# working on stack trace on issue 23
#
# working on stack trace on issue 25

# %%
# STATISTICS
# find the average of different connections for every file
# find maximum occurance frequency
# find number of different files
total_number  = 0
total_counter = 0
max_occur     = -1

for key in filenames_dict:
    total_counter      = total_counter + 1
    
    if len(filenames_dict[key]) > max_occur:
        max_occur = len(filenames_dict[key])
    
    total_number       = total_number + len(filenames_dict[key])

print("number of different files",total_counter)
print("the mean occurance rate is",total_number/total_counter)
print("maximum occurance frequensy",max_occur)
print("total number of stack traces",stack_traces_counter)
# Out:
# number of different files 1282
# the mean occurance rate is 2.0226209048361934
# maximum occurance frequensy 48
# total number of stack traces 522

# %%
# create histogram with occurance rates

frequencies = np.zeros(max_occur+1)
freq_index  = [i for i in range(max_occur+1)]

for key in filenames_dict:
    
    freq = len(filenames_dict[key])
    frequencies[freq]  += 1
    
plt.figure(figsize=(50, 6))
plt_item = plt.subplot(132)
plt_item.bar(freq_index,frequencies)
plt_item.set_xticks(np.arange(len(freq_index)))
plt_item.set_xticklabels(freq_index)
plt.xlabel("diaforetikes sindeseis")
plt.ylabel("plithos sinartisewn")
plt.show()

# %%
# for debugging purposes print the connections and occurance rate for each file 
for key in filenames_dict:
    print("file:",key," connects")
    for connection in filenames_dict[key]:
        print(connection["name"],connection["occurance"],connection["location"])
    print("++++++++++++++++++++")
# Out:
# file: org.json.JSONObject  connects
# org.json.JSONObject 4 ['page143_issue5', 'page178_issue14', 'page199_issue18', 'page195_issue21']
# cgeo.geocaching.connector.oc.OkapiClient 1 ['page143_issue5']
# cgeo.geocaching.network.Network 1 ['page178_issue14']
# cgeo.geocaching.connecor.gc.GCBase 1 ['page199_issue18']
# cgeo.geocaching.network.StatusUpdater 1 ['page195_issue21']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.oc.OkapiClient  connects
# cgeo.geocaching.connector.oc.OkapiClient 7 ['page143_issue5', 'page104_issue11', 'page125_issue3', 'page125_issue16', 'page130_issue14']
# cgeo.geocaching.connector.oc.OCApiLiveConnector 3 ['page143_issue5', 'page125_issue16', 'page130_issue14']
# cgeo.geocaching.connector.oc.OCApiConnector 2 ['page104_issue11', 'page125_issue3']
# cgeo.geocaching.connector.oc.OCApiConnector$1 1 ['page77_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.oc.OCApiLiveConnector  connects
# cgeo.geocaching.loaders.FinderGeocacheListLoader 1 ['page143_issue5']
# cgeo.geocaching.connector.ConnectorFactory$1 1 ['page125_issue16']
# cgeo.geocaching.utils.LogTemplateProvider$5 1 ['page130_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.loaders.FinderGeocacheListLoader  connects
# cgeo.geocaching.loaders.AbstractSearchLoader 1 ['page143_issue5']
# ++++++++++++++++++++
# file: cgeo.geocaching.loaders.AbstractSearchLoader  connects
# cgeo.geocaching.loaders.AbstractSearchLoader 1 ['page143_issue5']
# android.support.v4.content.AsyncTaskLoader 1 ['page143_issue5']
# cgeo.geocaching.connector.gc.RecaptchaHandler$4 1 ['page127_issue20']
# ++++++++++++++++++++
# file: android.support.v4.content.AsyncTaskLoader  connects
# android.support.v4.content.AsyncTaskLoader$LoadTask 5 ['page143_issue5', 'page47_issue22', 'page61_issue11', 'page152_issue4', 'page173_issue21']
# ++++++++++++++++++++
# file: android.support.v4.content.AsyncTaskLoader$LoadTask  connects
# android.support.v4.content.AsyncTaskLoader$LoadTask 1 ['page143_issue5']
# android.support.v4.content.ModernAsyncTask$2 1 ['page143_issue5']
# android.support.v4.content.ModernAsyncTask 4 ['page47_issue22', 'page61_issue11', 'page152_issue4', 'page173_issue21']
# ++++++++++++++++++++
# file: android.support.v4.content.ModernAsyncTask$2  connects
# java.util.concurrent.FutureTask 1 ['page143_issue5']
# ++++++++++++++++++++
# file: java.util.concurrent.FutureTask  connects
# java.util.concurrent.ThreadPoolExecutor 91 ['page143_issue5', 'page140_issue14', 'page37_issue5', 'page142_issue24', 'page174_issue6', 'page175_issue17', 'page17_issue1', 'page17_issue23', 'page158_issue2', 'page27_issue24', 'page138_issue9', 'page138_issue20', 'page14_issue18', 'page14_issue21', 'page134_issue23', 'page189_issue2', 'page168_issue17', 'page171_issue9', 'page135_issue25', 'page167_issue25', 'page137_issue22', 'page156_issue20']
# java.util.concurrent.FutureTask 28 ['page140_issue14', 'page4_issue8', 'page3_issue6', 'page27_issue23', 'page14_issue2', 'page60_issue17', 'page64_issue3', 'page109_issue18', 'page63_issue10', 'page63_issue21', 'page63_issue23', 'page92_issue16', 'page90_issue10', 'page156_issue20']
# java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask 17 ['page24_issue2', 'page43_issue16', 'page4_issue14', 'page27_issue22', 'page14_issue21', 'page60_issue7', 'page60_issue21', 'page64_issue24', 'page113_issue16', 'page113_issue17', 'page63_issue13', 'page63_issue14', 'page6_issue17', 'page112_issue14']
# java.util.concurrent.FutureTask$Sync 6 ['page142_issue24', 'page174_issue6', 'page138_issue20', 'page189_issue2', 'page168_issue17', 'page171_issue9']
# android.os.AsyncTask$SerialExecutor$1 15 ['page4_issue8', 'page4_issue23', 'page3_issue6', 'page27_issue23', 'page14_issue2', 'page60_issue17', 'page64_issue3', 'page109_issue18', 'page63_issue10', 'page63_issue21', 'page63_issue23', 'page92_issue16', 'page6_issue10', 'page90_issue10']
# android.os.Handler 3 ['page41_issue15', 'page20_issue12', 'page10_issue22']
# java.io.FileOutputStream 1 ['page60_issue17']
# ++++++++++++++++++++
# file: java.util.concurrent.ThreadPoolExecutor  connects
# java.util.concurrent.ThreadPoolExecutor$Worker 249 ['page143_issue5', 'page143_issue17', 'page31_issue6', 'page140_issue14', 'page180_issue1', 'page24_issue2', 'page47_issue22', 'page43_issue16', 'page37_issue5', 'page178_issue13', 'page36_issue16', 'page205_issue13', 'page142_issue4', 'page142_issue24', 'page174_issue6', 'page175_issue17', 'page78_issue1', 'page78_issue21', 'page123_issue3', 'page123_issue4', 'page102_issue10', 'page102_issue11', 'page17_issue1', 'page17_issue23', 'page4_issue8', 'page4_issue14', 'page4_issue23', 'page115_issue12', 'page104_issue7', 'page104_issue11', 'page104_issue25', 'page65_issue3', 'page96_issue14', 'page199_issue18', 'page38_issue8', 'page3_issue6', 'page125_issue3', 'page125_issue16', 'page27_issue22', 'page27_issue23', 'page27_issue24', 'page138_issue6', 'page138_issue9', 'page138_issue20', 'page14_issue2', 'page14_issue18', 'page14_issue21', 'page60_issue7', 'page60_issue17', 'page60_issue21', 'page134_issue23', 'page189_issue2', 'page64_issue3', 'page64_issue24', 'page168_issue17', 'page171_issue9', 'page105_issue1', 'page113_issue16', 'page113_issue17', 'page28_issue3', 'page106_issue2', 'page109_issue18', 'page196_issue10', 'page80_issue7', 'page135_issue25', 'page63_issue10', 'page63_issue13', 'page63_issue14', 'page63_issue21', 'page63_issue23', 'page92_issue16', 'page145_issue25', 'page6_issue10', 'page6_issue17', 'page87_issue15', 'page112_issue14', 'page136_issue14', 'page90_issue10', 'page77_issue18', 'page167_issue25', 'page176_issue9', 'page137_issue13', 'page137_issue18', 'page137_issue22', 'page156_issue20']
# java.util.concurrent.ThreadPoolExecutor 11 ['page143_issue9', 'page24_issue2', 'page14_issue21']
# android.os.AsyncTask 1 ['page143_issue9']
# java.util.concurrent.ScheduledThreadPoolExecutor 2 ['page60_issue7', 'page64_issue24']
# ++++++++++++++++++++
# file: java.util.concurrent.ThreadPoolExecutor$Worker  connects
# java.lang.Thread 250 ['page143_issue5', 'page143_issue17', 'page31_issue6', 'page140_issue14', 'page180_issue1', 'page24_issue2', 'page47_issue22', 'page43_issue16', 'page37_issue5', 'page178_issue13', 'page36_issue16', 'page205_issue13', 'page142_issue4', 'page142_issue24', 'page174_issue6', 'page175_issue17', 'page78_issue1', 'page78_issue21', 'page123_issue3', 'page123_issue4', 'page102_issue10', 'page102_issue11', 'page17_issue1', 'page17_issue23', 'page4_issue8', 'page4_issue14', 'page4_issue23', 'page115_issue12', 'page104_issue7', 'page104_issue11', 'page104_issue25', 'page65_issue3', 'page96_issue14', 'page199_issue18', 'page38_issue8', 'page3_issue6', 'page125_issue3', 'page125_issue16', 'page27_issue22', 'page27_issue23', 'page27_issue24', 'page138_issue6', 'page138_issue9', 'page138_issue20', 'page14_issue2', 'page14_issue18', 'page14_issue21', 'page60_issue7', 'page60_issue17', 'page60_issue21', 'page134_issue23', 'page189_issue2', 'page64_issue3', 'page64_issue24', 'page168_issue17', 'page171_issue9', 'page105_issue1', 'page113_issue16', 'page113_issue17', 'page28_issue3', 'page106_issue2', 'page109_issue18', 'page196_issue10', 'page80_issue7', 'page135_issue25', 'page63_issue10', 'page63_issue13', 'page63_issue14', 'page63_issue21', 'page63_issue23', 'page92_issue16', 'page145_issue25', 'page6_issue10', 'page6_issue17', 'page87_issue15', 'page112_issue14', 'page136_issue14', 'page90_issue10', 'page77_issue18', 'page167_issue25', 'page176_issue9', 'page137_issue13', 'page137_issue18', 'page137_issue22', 'page156_issue20']
# ++++++++++++++++++++
# file: android.database.sqlite.SQLiteProgram  connects
# cgeo.geocaching.DataStore 1 ['page143_issue6']
# android.database.sqlite.SQLiteQuery 1 ['page143_issue17']
# android.database.sqlite.SQLiteProgram 1 ['page192_issue5']
# android.database.sqlite.SQLiteStatement 2 ['page192_issue5', 'page83_issue9']
# ++++++++++++++++++++
# file: cgeo.geocaching.DataStore  connects
# cgeo.geocaching.DataStore 15 ['page143_issue6', 'page143_issue11', 'page104_issue11', 'page121_issue12', 'page112_issue14', 'page136_issue14', 'page137_issue13']
# cgeo.geocaching.connector.gc.GCParser 1 ['page143_issue6']
# cgeo.geocaching.DataStore$DbHelper 1 ['page143_issue11']
# cgeo.geocaching.MainActivity$CleanDatabaseThread 2 ['page143_issue11', 'page138_issue5']
# cgeo.geocaching.maps.CGeoMap$LoadRunnable 2 ['page143_issue17', 'page137_issue13']
# cgeo.geocaching.CacheDetailActivity 1 ['page124_issue16']
# cgeo.geocaching.CgeoApplication 2 ['page97_issue2', 'page109_issue25']
# cgeo.geocaching.connector.gc.GCParser$6 1 ['page102_issue11']
# cgeo.geocaching.MainActivity$CountBubbleUpdateThread 1 ['page115_issue24']
# cgeo.geocaching.connector.oc.OkapiClient 2 ['page104_issue11', 'page125_issue3']
# cgeo.geocaching.CacheListActivity 1 ['page113_issue20']
# cgeo.geocaching.search.SuggestionProvider 1 ['page121_issue12']
# cgeo.geocaching.Geocache 1 ['page135_issue25']
# cgeo.geocaching.SearchResult 3 ['page135_issue25', 'page136_issue14', 'page137_issue18']
# cgeo.geocaching.utils.DatabaseBackupUtils$3 1 ['page112_issue14']
# cgeo.geocaching.connector.gc.GCMap 1 ['page137_issue22']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.gc.GCParser  connects
# cgeo.geocaching.connector.gc.GCParser 101 ['page143_issue6', 'page180_issue1', 'page144_issue17', 'page78_issue1', 'page115_issue12', 'page165_issue13', 'page96_issue14', 'page134_issue23', 'page181_issue1', 'page80_issue7', 'page164_issue13', 'page176_issue9']
# cgeo.geocaching.connector.trackable.TravelBugConnector 1 ['page143_issue6']
# cgeo.geocaching.connector.gc.GCMap 89 ['page180_issue1', 'page115_issue12', 'page134_issue23', 'page80_issue7', 'page176_issue9']
# cgeo.geocaching.connector.gc.GCConnector 9 ['page147_issue18', 'page144_issue17', 'page78_issue1', 'page123_issue4', 'page165_issue13', 'page96_issue14', 'page181_issue1']
# cgeo.geocaching.connector.gc.GCLoggingManager 2 ['page158_issue2', 'page63_issue10']
# cgeo.geocaching.loaders.UsernameGeocacheListLoader 1 ['page164_issue13']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.trackable.TravelBugConnector  connects
# cgeo.geocaching.TrackableActivity$LoadTrackableThread 1 ['page143_issue6']
# ++++++++++++++++++++
# file: java.util.concurrent.ThreadPoolExecutor$AbortPolicy  connects
# java.util.concurrent.ThreadPoolExecutor 3 ['page143_issue9', 'page60_issue7', 'page64_issue24']
# ++++++++++++++++++++
# file: android.os.AsyncTask  connects
# android.os.AsyncTask 5 ['page143_issue9', 'page142_issue3', 'page44_issue10', 'page154_issue23']
# cgeo.geocaching.ui.ImagesList 1 ['page143_issue9']
# android.os.AsyncTask$InternalHandler 3 ['page142_issue3', 'page44_issue10', 'page154_issue23']
# cgeo.geocaching.LogCacheActivity$PostListener 1 ['page154_issue23']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.ImagesList  connects
# cgeo.geocaching.CacheDetailActivity 1 ['page143_issue9']
# cgeo.geocaching.ui.ImagesList 43 ['page17_issue23', 'page83_issue25']
# cgeo.geocaching.ui.-$$Lambda$ImagesList$w0Oezsdi_bTh50KSJpoGbCrmR5c 21 ['page17_issue23']
# cgeo.geocaching.ui.ImagesList$2 1 ['page83_issue25']
# ++++++++++++++++++++
# file: cgeo.geocaching.CacheDetailActivity  connects
# cgeo.geocaching.CacheDetailActivity 13 ['page143_issue9', 'page129_issue19', 'page27_issue23', 'page79_issue5', 'page127_issue12', 'page75_issue24', 'page10_issue22', 'page145_issue10', 'page145_issue11', 'page145_issue17', 'page122_issue15', 'page122_issue22']
# cgeo.geocaching.CacheDetailActivity$3 1 ['page143_issue9']
# android.app.Activity 11 ['page124_issue16', 'page85_issue4', 'page142_issue21', 'page76_issue20', 'page79_issue18', 'page127_issue12', 'page87_issue8', 'page29_issue19', 'page29_issue23']
# cgeo.geocaching.CacheDetailActivity$LoadCacheHandler 6 ['page129_issue19', 'page79_issue5', 'page127_issue12', 'page75_issue24', 'page122_issue15', 'page122_issue22']
# cgeo.geocaching.CacheDetailActivity$WaypointsViewCreator$2 1 ['page27_issue23']
# cgeo.geocaching.ui.EditNoteDialog$2 3 ['page66_issue22', 'page75_issue2', 'page75_issue22']
# cgeo.geocaching.activity.AbstractViewPagerActivity 2 ['page79_issue5', 'page75_issue24']
# cgeo.geocaching.CachePopupFragment$StoreCacheClickListener$3 1 ['page75_issue19']
# cgeo.geocaching.ui.NavigationActionProvider$1 1 ['page92_issue22']
# cgeo.geocaching.ui.EditNoteDialog 1 ['page10_issue22']
# android.app.Instrumentation 2 ['page145_issue10', 'page145_issue17']
# cgeo.geocaching.CacheDetailActivity$5 1 ['page145_issue11']
# android.view.View 2 ['page87_issue1', 'page136_issue12']
# cgeo.geocaching.CacheMenuHandler 1 ['page29_issue23']
# ++++++++++++++++++++
# file: cgeo.geocaching.CacheDetailActivity$3  connects
# cgeo.geocaching.activity.AbstractViewPagerActivity$1 1 ['page143_issue9']
# ++++++++++++++++++++
# file: cgeo.geocaching.activity.AbstractViewPagerActivity$1  connects
# com.viewpagerindicator.TitlePageIndicator 1 ['page143_issue9']
# ++++++++++++++++++++
# file: com.viewpagerindicator.TitlePageIndicator  connects
# android.support.v4.view.ViewPager 1 ['page143_issue9']
# android.view.View 1 ['page141_issue16']
# com.viewpagerindicator.TitlePageIndicator 1 ['page79_issue18']
# java.lang.reflect.Constructor 1 ['page79_issue18']
# ++++++++++++++++++++
# file: android.support.v4.view.ViewPager  connects
# android.support.v4.view.ViewPager 9 ['page143_issue9', 'page97_issue14', 'page145_issue17']
# android.view.View 2 ['page143_issue9', 'page187_issue15']
# android.support.v4.view.ViewPager$3 1 ['page97_issue14']
# android.view.ViewGroup 1 ['page97_issue14']
# android.support.v4.view.ViewPager$PagerObserver 1 ['page145_issue17']
# ++++++++++++++++++++
# file: android.view.View  connects
# android.view.ViewGroup 111 ['page143_issue9', 'page143_issue16', 'page100_issue1', 'page13_issue14', 'page144_issue10', 'page144_issue13', 'page81_issue2', 'page24_issue5', 'page43_issue6', 'page187_issue15', 'page142_issue21', 'page7_issue11', 'page208_issue16', 'page22_issue9', 'page99_issue12', 'page99_issue13', 'page141_issue16', 'page18_issue19', 'page1_issue16', 'page192_issue12', 'page121_issue1', 'page75_issue20', 'page200_issue18', 'page63_issue16', 'page110_issue7', 'page110_issue14', 'page112_issue2', 'page166_issue11']
# android.view.ViewRootImpl 10 ['page143_issue9', 'page143_issue16', 'page144_issue13', 'page187_issue15', 'page7_issue11', 'page97_issue14', 'page1_issue16', 'page192_issue12', 'page200_issue18']
# android.view.ViewRootImpl$ViewPostImeInputStage 7 ['page100_issue1', 'page43_issue6', 'page22_issue9', 'page99_issue12', 'page99_issue13', 'page63_issue16']
# android.view.View$PerformClick 21 ['page140_issue7', 'page144_issue18', 'page5_issue2', 'page178_issue15', 'page174_issue22', 'page8_issue12', 'page152_issue3', 'page163_issue20', 'page66_issue22', 'page181_issue1', 'page103_issue22', 'page106_issue18', 'page127_issue20', 'page170_issue21', 'page75_issue2', 'page75_issue22', 'page92_issue22', 'page10_issue22', 'page154_issue23', 'page154_issue25', 'page55_issue18']
# cgeo.geocaching.maps.google.GoogleMapView 1 ['page144_issue10']
# android.widget.FrameLayout 6 ['page144_issue10', 'page194_issue11', 'page141_issue16', 'page214_issue1']
# cgeo.geocaching.maps.google.v1.GoogleMapView 3 ['page81_issue2', 'page110_issue14']
# android.view.View 35 ['page81_issue2', 'page5_issue2', 'page8_issue12', 'page71_issue3', 'page70_issue24', 'page75_issue17', 'page110_issue14', 'page87_issue1']
# android.view.HardwareRenderer$GlRenderer 3 ['page81_issue2', 'page110_issue14']
# android.widget.TextView 5 ['page5_issue2', 'page54_issue21', 'page113_issue16', 'page87_issue1', 'page55_issue2']
# android.widget.ScrollView 2 ['page187_issue15', 'page7_issue11']
# android.support.v4.view.ViewPager 1 ['page187_issue15']
# android.widget.RelativeLayout 1 ['page7_issue11']
# cgeo.geocaching.ui.CompassMiniView 1 ['page202_issue17']
# android.widget.LinearLayout 2 ['page194_issue11', 'page214_issue1']
# android.view.ViewRoot 3 ['page194_issue11', 'page121_issue1', 'page214_issue1']
# android.widget.CompoundButton 1 ['page152_issue16']
# com.android.internal.widget.AlertDialogLayout 2 ['page1_issue16']
# android.widget.AbsListView 1 ['page71_issue3']
# android.support.v7.widget.RecyclerView 1 ['page70_issue24']
# android.widget.AdapterView 1 ['page75_issue17']
# com.android.internal.view.menu.ContextMenuBuilder 1 ['page87_issue1']
# ++++++++++++++++++++
# file: android.view.ViewGroup  connects
# android.view.ViewGroup 167 ['page143_issue9', 'page143_issue16', 'page100_issue1', 'page144_issue10', 'page144_issue13', 'page43_issue6', 'page208_issue16', 'page97_issue14', 'page22_issue9', 'page99_issue12', 'page99_issue13', 'page141_issue16', 'page192_issue12', 'page121_issue1', 'page75_issue17', 'page200_issue18', 'page63_issue16', 'page87_issue1']
# com.android.internal.policy.impl.PhoneWindow$DecorView 13 ['page143_issue9', 'page143_issue16', 'page144_issue13', 'page43_issue6', 'page97_issue14', 'page22_issue9', 'page99_issue12', 'page99_issue13', 'page192_issue12', 'page121_issue1', 'page200_issue18', 'page63_issue16']
# android.widget.PopupWindow$PopupViewContainer 1 ['page100_issue1']
# android.widget.LinearLayout 22 ['page13_issue14', 'page24_issue5', 'page187_issue15', 'page7_issue11', 'page18_issue19', 'page75_issue20', 'page110_issue7', 'page112_issue2', 'page166_issue11']
# android.widget.FrameLayout 30 ['page13_issue14', 'page24_issue5', 'page187_issue15', 'page7_issue11', 'page18_issue19', 'page1_issue16', 'page75_issue20', 'page110_issue7', 'page112_issue2', 'page166_issue11']
# androidx.appcompat.widget.ActionBarOverlayLayout 4 ['page13_issue14', 'page24_issue5', 'page7_issue11', 'page18_issue19']
# android.view.ViewRootImpl 6 ['page13_issue14', 'page18_issue19', 'page75_issue20', 'page110_issue7', 'page112_issue2', 'page166_issue11']
# android.view.View 31 ['page144_issue10', 'page81_issue2', 'page202_issue17', 'page141_issue16', 'page113_issue16', 'page75_issue17', 'page110_issue14', 'page87_issue1']
# android.sec.multiwindow.impl.BorderFrameLayout 1 ['page144_issue10']
# android.view.ViewRoot 2 ['page142_issue21', 'page208_issue16']
# android.widget.RelativeLayout 2 ['page1_issue16']
# com.android.internal.widget.ActionBarOverlayLayout 3 ['page75_issue20', 'page110_issue7', 'page112_issue2']
# android.widget.AbsListView 1 ['page87_issue1']
# ++++++++++++++++++++
# file: com.android.internal.policy.impl.PhoneWindow$DecorView  connects
# com.android.internal.policy.impl.PhoneWindow 13 ['page143_issue9', 'page143_issue16', 'page144_issue13', 'page43_issue6', 'page97_issue14', 'page22_issue9', 'page99_issue12', 'page99_issue13', 'page192_issue12', 'page121_issue1', 'page200_issue18', 'page63_issue16']
# android.view.View 14 ['page143_issue9', 'page143_issue16', 'page144_issue13', 'page187_issue15', 'page142_issue21', 'page97_issue14', 'page22_issue9', 'page99_issue12', 'page99_issue13', 'page192_issue12', 'page121_issue1', 'page200_issue18', 'page63_issue16']
# android.view.ViewRootImpl 3 ['page144_issue10', 'page169_issue1', 'page155_issue6']
# com.android.internal.policy.impl.MultiPhoneWindow$MultiPhoneDecorView 1 ['page43_issue6']
# android.view.ViewRoot 1 ['page141_issue16']
# android.view.ViewGroup 1 ['page87_issue1']
# ++++++++++++++++++++
# file: com.android.internal.policy.impl.PhoneWindow  connects
# android.app.Activity 16 ['page143_issue9', 'page143_issue16', 'page144_issue13', 'page43_issue6', 'page205_issue20', 'page142_issue1', 'page97_issue14', 'page192_issue12', 'page138_issue10', 'page79_issue18', 'page127_issue12', 'page121_issue1', 'page191_issue25', 'page63_issue16']
# com.android.internal.view.menu.MenuItemImpl 2 ['page180_issue9', 'page147_issue18']
# com.android.internal.app.AlertController 7 ['page43_issue6', 'page22_issue6', 'page22_issue9', 'page41_issue15']
# com.android.internal.policy.impl.PhoneWindow 15 ['page85_issue4', 'page142_issue21', 'page169_issue1', 'page41_issue15', 'page105_issue25', 'page70_issue2', 'page127_issue11', 'page127_issue12', 'page155_issue6', 'page87_issue8']
# com.android.internal.policy.impl.PhoneWindow$1 5 ['page85_issue4', 'page105_issue25', 'page70_issue2', 'page127_issue11', 'page87_issue8']
# com.android.internal.policy.impl.PhoneWindow$DecorView 3 ['page142_issue21', 'page169_issue1', 'page155_issue6']
# android.app.Dialog 5 ['page22_issue9', 'page99_issue12', 'page99_issue13', 'page200_issue18']
# com.android.internal.view.menu.MenuBuilder 3 ['page189_issue8', 'page64_issue12', 'page168_issue16']
# ++++++++++++++++++++
# file: android.app.Activity  connects
# com.android.internal.policy.impl.PhoneWindow$DecorView 7 ['page143_issue9', 'page143_issue16', 'page144_issue13', 'page43_issue6', 'page192_issue12', 'page121_issue1', 'page63_issue16']
# android.app.Instrumentation 44 ['page228_issue1', 'page124_issue16', 'page180_issue6', 'page180_issue15', 'page147_issue25', 'page5_issue15', 'page133_issue5', 'page205_issue20', 'page142_issue1', 'page23_issue7', 'page7_issue22', 'page7_issue23', 'page97_issue13', 'page62_issue12', 'page102_issue22', 'page102_issue25', 'page179_issue6', 'page4_issue25', 'page172_issue12', 'page2_issue9', 'page18_issue1', 'page11_issue17', 'page19_issue17', 'page41_issue22', 'page20_issue9', 'page79_issue18', 'page146_issue4', 'page121_issue18', 'page30_issue9', 'page63_issue22', 'page110_issue9', 'page6_issue6', 'page155_issue4', 'page155_issue8', 'page136_issue17', 'page77_issue17', 'page130_issue14']
# android.app.ActivityThread 19 ['page140_issue15', 'page5_issue14', 'page36_issue13', 'page142_issue5', 'page8_issue17', 'page44_issue9', 'page41_issue18', 'page171_issue10', 'page70_issue9', 'page92_issue13', 'page145_issue10', 'page145_issue17', 'page6_issue18', 'page112_issue13', 'page68_issue24', 'page136_issue16', 'page42_issue3', 'page42_issue4']
# com.android.internal.policy.impl.PhoneWindow 4 ['page180_issue9', 'page169_issue1', 'page189_issue8', 'page155_issue6']
# android.support.v4.app.FragmentActivity 18 ['page147_issue18', 'page85_issue4', 'page142_issue21', 'page174_issue22', 'page44_issue8', 'page44_issue10', 'page123_issue2', 'page76_issue20', 'page99_issue13', 'page41_issue15', 'page64_issue12', 'page168_issue16', 'page105_issue25', 'page103_issue22', 'page127_issue11', 'page127_issue12', 'page87_issue8']
# android.app.Activity 30 ['page5_issue15', 'page23_issue7', 'page174_issue22', 'page44_issue10', 'page7_issue22', 'page7_issue23', 'page4_issue13', 'page4_issue25', 'page2_issue9', 'page18_issue1', 'page11_issue17', 'page192_issue12', 'page19_issue17', 'page168_issue16', 'page70_issue9', 'page30_issue9', 'page6_issue6', 'page68_issue24', 'page122_issue23']
# cgeo.geocaching.maps.CGeoMap 3 ['page205_issue20', 'page142_issue1', 'page191_issue25']
# cgeo.geocaching.SearchActivity 1 ['page174_issue22']
# cgeo.geocaching.utils.ShareUtils 1 ['page44_issue10']
# android.support.v7.app.ActionBarActivityDelegateICS$WindowCallbackWrapper 1 ['page97_issue14']
# androidx.fragment.app.FragmentActivity 13 ['page17_issue1', 'page18_issue5', 'page29_issue19', 'page29_issue23']
# cgeo.geocaching.cgeocaches 1 ['page172_issue12']
# android.text.style.URLSpan 1 ['page192_issue12']
# cgeo.geocaching.activity.AbstractActivity 1 ['page138_issue10']
# com.android.internal.policy.PhoneWindow 2 ['page20_issue12', 'page15_issue3']
# android.support.v7.app.ActionBarActivity 3 ['page79_issue18']
# android.support.v4.app.ActivityCompatHoneycomb 1 ['page127_issue12']
# cgeo.geocaching.settings.SettingsActivity$1 1 ['page122_issue23']
# ++++++++++++++++++++
# file: android.view.ViewRootImpl  connects
# android.view.ViewRootImpl 66 ['page143_issue9', 'page143_issue16', 'page100_issue1', 'page13_issue14', 'page144_issue10', 'page144_issue13', 'page81_issue2', 'page187_issue15', 'page7_issue11', 'page97_issue14', 'page99_issue12', 'page18_issue19', 'page1_issue16', 'page192_issue12', 'page169_issue1', 'page71_issue3', 'page70_issue24', 'page75_issue17', 'page75_issue20', 'page200_issue18', 'page63_issue16', 'page110_issue7', 'page110_issue14', 'page155_issue6', 'page112_issue2', 'page166_issue11']
# android.view.ViewRootImpl$WindowInputEventReceiver 7 ['page143_issue9', 'page143_issue16', 'page100_issue1', 'page144_issue13', 'page97_issue14', 'page99_issue12', 'page63_issue16']
# android.view.ViewRootImpl$ConsumeBatchedInputRunnable 2 ['page143_issue16', 'page63_issue16']
# android.view.WindowManagerImpl 1 ['page180_issue6']
# android.view.ViewRootImpl$TraversalRunnable 14 ['page13_issue14', 'page144_issue10', 'page81_issue2', 'page187_issue15', 'page7_issue11', 'page18_issue19', 'page1_issue16', 'page75_issue20', 'page110_issue7', 'page110_issue14', 'page112_issue2', 'page166_issue11']
# android.view.WindowManagerGlobal 2 ['page97_issue3', 'page154_issue23']
# android.os.Handler 2 ['page192_issue12', 'page200_issue18']
# android.view.ViewRootImpl$ViewRootHandler 2 ['page169_issue1', 'page155_issue6']
# android.view.View 2 ['page71_issue3', 'page70_issue24']
# android.view.ViewGroup 1 ['page75_issue17']
# ++++++++++++++++++++
# file: android.view.ViewRootImpl$WindowInputEventReceiver  connects
# android.view.InputEventReceiver 7 ['page143_issue9', 'page143_issue16', 'page100_issue1', 'page144_issue13', 'page97_issue14', 'page99_issue12', 'page63_issue16']
# ++++++++++++++++++++
# file: android.view.InputEventReceiver  connects
# android.os.MessageQueue 5 ['page143_issue9', 'page100_issue1', 'page144_issue13', 'page97_issue14', 'page99_issue12']
# android.view.InputEventReceiver 4 ['page143_issue16', 'page63_issue16']
# android.view.ViewRootImpl 2 ['page143_issue16', 'page63_issue16']
# ++++++++++++++++++++
# file: android.os.MessageQueue  connects
# android.os.MessageQueue 7 ['page143_issue9', 'page100_issue1', 'page114_issue5', 'page144_issue13', 'page97_issue14', 'page99_issue12', 'page122_issue7']
# android.os.Looper 7 ['page143_issue9', 'page100_issue1', 'page114_issue5', 'page144_issue13', 'page97_issue14', 'page99_issue12', 'page122_issue7']
# ++++++++++++++++++++
# file: android.os.Looper  connects
# android.app.ActivityThread 307 ['page143_issue9', 'page143_issue13', 'page143_issue16', 'page32_issue17', 'page228_issue1', 'page100_issue1', 'page114_issue5', 'page124_issue16', 'page140_issue7', 'page140_issue15', 'page180_issue6', 'page180_issue9', 'page180_issue11', 'page13_issue2', 'page13_issue3', 'page13_issue13', 'page13_issue14', 'page147_issue18', 'page147_issue25', 'page144_issue10', 'page144_issue13', 'page144_issue18', 'page81_issue2', 'page5_issue1', 'page5_issue2', 'page5_issue14', 'page5_issue15', 'page221_issue12', 'page236_issue22', 'page133_issue5', 'page47_issue22', 'page61_issue11', 'page85_issue4', 'page178_issue15', 'page36_issue13', 'page187_issue15', 'page205_issue12', 'page205_issue20', 'page142_issue1', 'page142_issue3', 'page142_issue5', 'page142_issue21', 'page23_issue7', 'page174_issue22', 'page8_issue6', 'page8_issue12', 'page8_issue17', 'page16_issue24', 'page44_issue8', 'page44_issue9', 'page44_issue10', 'page7_issue11', 'page7_issue22', 'page7_issue23', 'page208_issue16', 'page186_issue23', 'page97_issue2', 'page97_issue3', 'page97_issue4', 'page97_issue13', 'page97_issue14', 'page123_issue1', 'page123_issue2', 'page123_issue10', 'page62_issue12', 'page102_issue9', 'page102_issue10', 'page102_issue22', 'page102_issue25', 'page17_issue1', 'page17_issue23', 'page230_issue5', 'page179_issue4', 'page179_issue6', 'page4_issue7', 'page4_issue13', 'page4_issue23', 'page4_issue25', 'page76_issue20', 'page115_issue5', 'page115_issue6', 'page95_issue22', 'page22_issue6', 'page227_issue10', 'page129_issue19', 'page172_issue12', 'page99_issue12', 'page128_issue23', 'page194_issue11', 'page96_issue2', 'page96_issue20', 'page152_issue3', 'page152_issue4', 'page152_issue16', 'page74_issue5', 'page3_issue18', 'page2_issue9', 'page141_issue16', 'page18_issue1', 'page18_issue4', 'page18_issue5', 'page18_issue19', 'page11_issue17', 'page218_issue17', 'page1_issue16', 'page192_issue12', 'page19_issue17', 'page219_issue22', 'page169_issue1', 'page66_issue22', 'page138_issue3', 'page138_issue4', 'page138_issue9', 'page138_issue10', 'page71_issue14', 'page54_issue21', 'page41_issue8', 'page41_issue15', 'page41_issue18', 'page41_issue22', 'page20_issue9', 'page20_issue12', 'page60_issue18', 'page60_issue20', 'page60_issue21', 'page189_issue8', 'page64_issue12', 'page79_issue5', 'page79_issue18', 'page168_issue16', 'page171_issue7', 'page171_issue10', 'page105_issue25', 'page113_issue13', 'page113_issue15', 'page113_issue20', 'page28_issue20', 'page28_issue22', 'page28_issue24', 'page116_issue23', 'page181_issue1', 'page103_issue16', 'page103_issue22', 'page70_issue2', 'page70_issue9', 'page146_issue4', 'page50_issue9', 'page50_issue11', 'page106_issue18', 'page127_issue11', 'page127_issue12', 'page127_issue20', 'page170_issue21', 'page48_issue2', 'page109_issue25', 'page196_issue9', 'page196_issue11', 'page121_issue1', 'page121_issue4', 'page121_issue13', 'page121_issue14', 'page121_issue18', 'page214_issue1', 'page12_issue10', 'page12_issue24', 'page75_issue2', 'page75_issue19', 'page75_issue20', 'page75_issue22', 'page75_issue23', 'page75_issue24', 'page75_issue25', 'page83_issue25', 'page200_issue18', 'page191_issue20', 'page191_issue25', 'page30_issue9', 'page148_issue11', 'page63_issue15', 'page63_issue16', 'page63_issue17', 'page63_issue20', 'page63_issue22', 'page92_issue12', 'page92_issue13', 'page92_issue22', 'page110_issue7', 'page110_issue8', 'page110_issue9', 'page110_issue14', 'page110_issue19', 'page10_issue22', 'page145_issue10', 'page145_issue11', 'page145_issue17', 'page6_issue6', 'page6_issue18', 'page155_issue4', 'page155_issue6', 'page155_issue7', 'page155_issue8', 'page155_issue9', 'page87_issue1', 'page87_issue8', 'page87_issue16', 'page87_issue20', 'page112_issue2', 'page112_issue13', 'page112_issue14', 'page68_issue24', 'page136_issue16', 'page136_issue17', 'page166_issue11', 'page232_issue15', 'page77_issue17', 'page77_issue18', 'page15_issue3', 'page154_issue23', 'page154_issue25', 'page55_i ...
# cgeo.geocaching.network.StatusUpdater 3 ['page178_issue14', 'page195_issue21', 'page185_issue7']
# android.os.HandlerThread 5 ['page97_issue4', 'page113_issue3', 'page113_issue13', 'page121_issue12', 'page87_issue20']
# ++++++++++++++++++++
# file: android.app.ActivityThread  connects
# java.lang.reflect.Method 306 ['page143_issue9', 'page143_issue13', 'page143_issue16', 'page32_issue17', 'page228_issue1', 'page100_issue1', 'page114_issue5', 'page124_issue16', 'page140_issue7', 'page140_issue15', 'page180_issue6', 'page180_issue9', 'page180_issue11', 'page13_issue2', 'page13_issue3', 'page13_issue13', 'page13_issue14', 'page147_issue18', 'page147_issue25', 'page144_issue10', 'page144_issue13', 'page144_issue18', 'page81_issue2', 'page5_issue1', 'page5_issue2', 'page5_issue14', 'page5_issue15', 'page221_issue12', 'page236_issue22', 'page133_issue5', 'page47_issue22', 'page61_issue11', 'page85_issue4', 'page178_issue15', 'page36_issue13', 'page187_issue15', 'page205_issue12', 'page205_issue20', 'page142_issue1', 'page142_issue3', 'page142_issue5', 'page142_issue21', 'page23_issue7', 'page174_issue22', 'page8_issue6', 'page8_issue12', 'page8_issue17', 'page16_issue24', 'page44_issue8', 'page44_issue9', 'page44_issue10', 'page7_issue11', 'page7_issue22', 'page7_issue23', 'page208_issue16', 'page186_issue23', 'page97_issue2', 'page97_issue3', 'page97_issue4', 'page97_issue13', 'page97_issue14', 'page123_issue1', 'page123_issue2', 'page123_issue10', 'page62_issue12', 'page102_issue9', 'page102_issue10', 'page102_issue22', 'page102_issue25', 'page17_issue1', 'page17_issue23', 'page230_issue5', 'page179_issue4', 'page179_issue6', 'page4_issue7', 'page4_issue13', 'page4_issue23', 'page4_issue25', 'page76_issue20', 'page115_issue5', 'page115_issue6', 'page95_issue22', 'page22_issue6', 'page227_issue10', 'page129_issue19', 'page172_issue12', 'page99_issue12', 'page128_issue23', 'page194_issue11', 'page96_issue2', 'page96_issue20', 'page152_issue3', 'page152_issue4', 'page152_issue16', 'page74_issue5', 'page3_issue18', 'page2_issue9', 'page141_issue16', 'page18_issue1', 'page18_issue4', 'page18_issue5', 'page18_issue19', 'page11_issue17', 'page218_issue17', 'page1_issue16', 'page192_issue12', 'page19_issue17', 'page219_issue22', 'page169_issue1', 'page66_issue22', 'page138_issue3', 'page138_issue4', 'page138_issue9', 'page138_issue10', 'page71_issue14', 'page54_issue21', 'page41_issue8', 'page41_issue15', 'page41_issue18', 'page41_issue22', 'page20_issue9', 'page20_issue12', 'page60_issue18', 'page60_issue20', 'page60_issue21', 'page189_issue8', 'page64_issue12', 'page79_issue5', 'page79_issue18', 'page168_issue16', 'page171_issue7', 'page171_issue10', 'page105_issue25', 'page113_issue13', 'page113_issue15', 'page113_issue20', 'page28_issue20', 'page28_issue22', 'page28_issue24', 'page116_issue23', 'page181_issue1', 'page103_issue16', 'page103_issue22', 'page70_issue2', 'page70_issue9', 'page146_issue4', 'page50_issue9', 'page50_issue11', 'page106_issue18', 'page127_issue11', 'page127_issue12', 'page127_issue20', 'page170_issue21', 'page48_issue2', 'page109_issue25', 'page196_issue9', 'page196_issue11', 'page121_issue1', 'page121_issue4', 'page121_issue13', 'page121_issue14', 'page121_issue18', 'page214_issue1', 'page12_issue10', 'page12_issue24', 'page75_issue2', 'page75_issue19', 'page75_issue20', 'page75_issue22', 'page75_issue23', 'page75_issue24', 'page75_issue25', 'page83_issue25', 'page200_issue18', 'page191_issue20', 'page191_issue25', 'page30_issue9', 'page148_issue11', 'page63_issue15', 'page63_issue16', 'page63_issue17', 'page63_issue20', 'page63_issue22', 'page92_issue12', 'page92_issue13', 'page92_issue22', 'page110_issue7', 'page110_issue8', 'page110_issue9', 'page110_issue14', 'page110_issue19', 'page10_issue22', 'page145_issue10', 'page145_issue11', 'page145_issue17', 'page6_issue6', 'page6_issue18', 'page155_issue4', 'page155_issue6', 'page155_issue7', 'page155_issue8', 'page155_issue9', 'page87_issue1', 'page87_issue8', 'page87_issue16', 'page87_issue20', 'page112_issue2', 'page112_issue13', 'page112_issue14', 'page68_issue24', 'page136_issue16', 'page136_issue17', 'page166_issue11', 'page232_issue15', 'page77_issue17', 'page77_issue18', 'page15_issue3', 'page154_issue23', 'page154_issue25', 'page55_iss ...
# android.app.ActivityThread 142 ['page228_issue1', 'page124_issue16', 'page140_issue15', 'page180_issue6', 'page180_issue11', 'page13_issue3', 'page147_issue25', 'page5_issue14', 'page5_issue15', 'page221_issue12', 'page133_issue5', 'page36_issue13', 'page205_issue20', 'page142_issue1', 'page142_issue5', 'page23_issue7', 'page8_issue17', 'page16_issue24', 'page7_issue22', 'page7_issue23', 'page97_issue2', 'page97_issue13', 'page62_issue12', 'page102_issue22', 'page102_issue25', 'page179_issue6', 'page4_issue13', 'page4_issue25', 'page227_issue10', 'page172_issue12', 'page2_issue9', 'page18_issue1', 'page18_issue4', 'page11_issue17', 'page218_issue17', 'page19_issue17', 'page219_issue22', 'page138_issue10', 'page41_issue18', 'page41_issue22', 'page20_issue9', 'page60_issue20', 'page35_issue9', 'page79_issue18', 'page171_issue7', 'page171_issue10', 'page113_issue20', 'page28_issue22', 'page70_issue9', 'page146_issue4', 'page109_issue25', 'page121_issue18', 'page191_issue25', 'page30_issue9', 'page148_issue11', 'page63_issue22', 'page92_issue13', 'page110_issue9', 'page110_issue19', 'page145_issue10', 'page145_issue17', 'page6_issue6', 'page155_issue4', 'page155_issue8', 'page112_issue13', 'page68_issue24', 'page136_issue16', 'page136_issue17', 'page77_issue17', 'page77_issue18', 'page137_issue17', 'page42_issue3', 'page42_issue4', 'page130_issue14']
# android.app.ActivityThread$H 63 ['page228_issue1', 'page124_issue16', 'page140_issue15', 'page180_issue6', 'page180_issue11', 'page13_issue3', 'page147_issue25', 'page221_issue12', 'page133_issue5', 'page36_issue13', 'page205_issue20', 'page142_issue1', 'page142_issue5', 'page16_issue24', 'page97_issue2', 'page97_issue13', 'page62_issue12', 'page102_issue22', 'page102_issue25', 'page179_issue6', 'page227_issue10', 'page172_issue12', 'page18_issue4', 'page218_issue17', 'page219_issue22', 'page138_issue10', 'page41_issue18', 'page41_issue22', 'page20_issue9', 'page60_issue20', 'page79_issue18', 'page171_issue7', 'page171_issue10', 'page113_issue20', 'page70_issue9', 'page146_issue4', 'page109_issue25', 'page121_issue18', 'page191_issue25', 'page148_issue11', 'page63_issue17', 'page63_issue22', 'page92_issue13', 'page110_issue9', 'page110_issue19', 'page145_issue10', 'page145_issue17', 'page155_issue4', 'page155_issue8', 'page112_issue13', 'page68_issue24', 'page136_issue16', 'page136_issue17', 'page77_issue17', 'page77_issue18', 'page137_issue17', 'page42_issue3', 'page130_issue14']
# android.database.sqlite.SQLiteConnection 1 ['page13_issue3']
# android.app.servertransaction.ActivityResultItem 3 ['page5_issue14', 'page8_issue17']
# android.app.servertransaction.LaunchActivityItem 16 ['page5_issue15', 'page23_issue7', 'page7_issue22', 'page7_issue23', 'page4_issue13', 'page4_issue25', 'page2_issue9', 'page18_issue1', 'page19_issue17', 'page30_issue9', 'page6_issue6']
# java.lang.Class 1 ['page133_issue5']
# java.lang.reflect.Constructor 2 ['page205_issue20', 'page142_issue1']
# android.app.servertransaction.TransactionExecutor 3 ['page44_issue9', 'page6_issue18']
# android.app.servertransaction.ActivityRelaunchItem 1 ['page11_issue17']
# android.app.servertransaction.ResumeActivityItem 2 ['page28_issue22', 'page42_issue4']
# cgeo.geocaching.maps.mapsforge.v024.MapsforgeMapView024 1 ['page191_issue25']
# ++++++++++++++++++++
# file: java.lang.reflect.Method  connects
# java.lang.reflect.Method 172 ['page143_issue9', 'page143_issue13', 'page143_issue16', 'page228_issue1', 'page100_issue1', 'page114_issue5', 'page124_issue16', 'page140_issue7', 'page140_issue15', 'page180_issue6', 'page180_issue9', 'page180_issue11', 'page147_issue18', 'page147_issue25', 'page144_issue10', 'page144_issue13', 'page144_issue18', 'page81_issue2', 'page221_issue12', 'page236_issue22', 'page133_issue5', 'page47_issue22', 'page85_issue4', 'page178_issue15', 'page187_issue15', 'page205_issue12', 'page205_issue20', 'page142_issue1', 'page142_issue3', 'page142_issue5', 'page142_issue21', 'page174_issue22', 'page208_issue16', 'page186_issue23', 'page97_issue2', 'page97_issue3', 'page97_issue4', 'page97_issue13', 'page97_issue14', 'page123_issue1', 'page123_issue2', 'page123_issue10', 'page102_issue9', 'page102_issue10', 'page102_issue22', 'page102_issue25', 'page230_issue5', 'page179_issue4', 'page179_issue6', 'page115_issue5', 'page115_issue6', 'page95_issue22', 'page22_issue6', 'page227_issue10', 'page129_issue19', 'page172_issue12', 'page99_issue12', 'page128_issue23', 'page194_issue11', 'page96_issue2', 'page96_issue20', 'page152_issue3', 'page152_issue4', 'page152_issue16', 'page141_issue16', 'page218_issue17', 'page192_issue12', 'page219_issue22', 'page169_issue1', 'page138_issue3', 'page138_issue4', 'page138_issue9', 'page138_issue10', 'page71_issue14', 'page41_issue8', 'page41_issue15', 'page60_issue20', 'page189_issue8', 'page64_issue12', 'page79_issue5', 'page79_issue18', 'page168_issue16', 'page171_issue7', 'page171_issue10', 'page105_issue25', 'page113_issue13', 'page113_issue15', 'page113_issue20', 'page116_issue23', 'page181_issue1', 'page103_issue16', 'page103_issue22', 'page70_issue2', 'page146_issue4', 'page106_issue18', 'page127_issue11', 'page127_issue12', 'page127_issue20', 'page170_issue21', 'page109_issue25', 'page196_issue9', 'page196_issue11', 'page121_issue1', 'page121_issue4', 'page121_issue13', 'page121_issue14', 'page121_issue18', 'page214_issue1', 'page75_issue2', 'page75_issue19', 'page75_issue20', 'page75_issue23', 'page75_issue24', 'page75_issue25', 'page83_issue9', 'page83_issue25', 'page200_issue18', 'page191_issue20', 'page191_issue25', 'page148_issue11', 'page63_issue15', 'page63_issue16', 'page63_issue17', 'page92_issue12', 'page92_issue13', 'page92_issue22', 'page110_issue7', 'page110_issue8', 'page110_issue9', 'page110_issue14', 'page110_issue19', 'page10_issue22', 'page145_issue10', 'page145_issue11', 'page145_issue17', 'page155_issue4', 'page155_issue6', 'page155_issue7', 'page155_issue8', 'page155_issue9', 'page87_issue1', 'page87_issue8', 'page87_issue16', 'page87_issue20', 'page112_issue2', 'page112_issue13', 'page112_issue14', 'page136_issue16', 'page136_issue17', 'page166_issue11', 'page232_issue15', 'page154_issue23', 'page154_issue25', 'page29_issue19', 'page137_issue17', 'page130_issue10', 'page130_issue14', 'page173_issue21', 'page101_issue20', 'page122_issue7', 'page122_issue22', 'page122_issue23', 'page122_issue25']
# com.android.internal.os.ZygoteInit$MethodAndArgsCaller 192 ['page143_issue9', 'page143_issue13', 'page143_issue16', 'page32_issue17', 'page228_issue1', 'page100_issue1', 'page114_issue5', 'page124_issue16', 'page140_issue7', 'page140_issue15', 'page180_issue6', 'page180_issue9', 'page180_issue11', 'page13_issue3', 'page147_issue18', 'page147_issue25', 'page144_issue10', 'page144_issue13', 'page144_issue18', 'page81_issue2', 'page221_issue12', 'page236_issue22', 'page133_issue5', 'page47_issue22', 'page61_issue11', 'page85_issue4', 'page178_issue15', 'page187_issue15', 'page205_issue12', 'page205_issue20', 'page142_issue1', 'page142_issue3', 'page142_issue5', 'page142_issue21', 'page174_issue22', 'page208_issue16', 'page186_issue23', 'page97_issue2', 'page97_issue3', 'page97_issue4', 'page97_issue13', 'page97_issue14', 'page123_issue1', 'page123_issue2', 'page123_issue10', 'page62_issue12', 'page102_issue9', 'page102_issue10', 'page102_issue22', 'page102_issue25', 'page230_issue5', 'page179_issue4', 'page179_issue6', 'page76_issue20', 'page115_issue5', 'page115_issue6', 'page95_issue22', 'page22_issue6', 'page227_issue10', 'page129_issue19', 'page172_issue12', 'page128_issue23', 'page194_issue11', 'page96_issue2', 'page96_issue20', 'page152_issue3', 'page152_issue4', 'page152_issue16', 'page74_issue5', 'page141_issue16', 'page218_issue17', 'page192_issue12', 'page219_issue22', 'page169_issue1', 'page66_issue22', 'page138_issue3', 'page138_issue4', 'page138_issue9', 'page138_issue10', 'page71_issue14', 'page54_issue21', 'page41_issue8', 'page41_issue15', 'page60_issue18', 'page60_issue20', 'page60_issue21', 'page189_issue8', 'page64_issue12', 'page79_issue5', 'page79_issue18', 'page168_issue16', 'page171_issue7', 'page171_issue10', 'page105_issue25', 'page113_issue13', 'page113_issue15', 'page113_issue20', 'page116_issue23', 'page181_issue1', 'page103_issue16', 'page103_issue22', 'page70_issue2', 'page70_issue9', 'page50_issue9', 'page106_issue18', 'page127_issue11', 'page127_issue12', 'page127_issue20', 'page170_issue21', 'page109_issue25', 'page196_issue9', 'page196_issue11', 'page121_issue1', 'page121_issue4', 'page121_issue13', 'page121_issue14', 'page121_issue18', 'page214_issue1', 'page75_issue2', 'page75_issue19', 'page75_issue20', 'page75_issue22', 'page75_issue23', 'page75_issue24', 'page75_issue25', 'page83_issue25', 'page200_issue18', 'page191_issue20', 'page191_issue25', 'page148_issue11', 'page63_issue15', 'page63_issue16', 'page63_issue17', 'page63_issue20', 'page63_issue22', 'page92_issue12', 'page92_issue13', 'page92_issue22', 'page110_issue7', 'page110_issue8', 'page110_issue9', 'page110_issue14', 'page110_issue19', 'page10_issue22', 'page145_issue10', 'page145_issue11', 'page145_issue17', 'page155_issue4', 'page155_issue6', 'page155_issue7', 'page155_issue8', 'page155_issue9', 'page87_issue1', 'page87_issue8', 'page87_issue16', 'page87_issue20', 'page112_issue2', 'page112_issue13', 'page112_issue14', 'page68_issue24', 'page136_issue16', 'page136_issue17', 'page166_issue11', 'page232_issue15', 'page77_issue17', 'page77_issue18', 'page154_issue23', 'page154_issue25', 'page55_issue2', 'page55_issue18', 'page29_issue19', 'page137_issue17', 'page57_issue23', 'page130_issue10', 'page130_issue14', 'page173_issue21', 'page101_issue20', 'page122_issue7', 'page122_issue22', 'page122_issue23', 'page122_issue25']
# com.android.internal.os.RuntimeInit$MethodAndArgsCaller 105 ['page13_issue2', 'page13_issue13', 'page13_issue14', 'page5_issue1', 'page5_issue2', 'page5_issue14', 'page5_issue15', 'page23_issue7', 'page8_issue6', 'page8_issue12', 'page8_issue17', 'page16_issue24', 'page44_issue8', 'page44_issue9', 'page7_issue11', 'page7_issue22', 'page7_issue23', 'page17_issue1', 'page17_issue23', 'page4_issue7', 'page4_issue13', 'page4_issue23', 'page4_issue25', 'page3_issue18', 'page2_issue9', 'page18_issue1', 'page18_issue4', 'page18_issue5', 'page18_issue19', 'page11_issue17', 'page1_issue16', 'page19_issue17', 'page20_issue12', 'page28_issue20', 'page28_issue22', 'page28_issue24', 'page12_issue10', 'page12_issue24', 'page30_issue9', 'page6_issue6', 'page6_issue18', 'page15_issue3', 'page29_issue23', 'page42_issue4']
# junit.framework.TestCase 3 ['page37_issue5', 'page7_issue15', 'page6_issue13']
# com.android.internal.os.Zygote$MethodAndArgsCaller 8 ['page36_issue13', 'page44_issue10', 'page41_issue18', 'page41_issue22', 'page20_issue9', 'page50_issue11', 'page48_issue2', 'page42_issue3']
# android.test.AndroidTestRunner 3 ['page175_issue10', 'page146_issue12', 'page173_issue23']
# android.test.InstrumentationTestCase 4 ['page175_issue11', 'page102_issue7', 'page105_issue14', 'page57_issue11']
# org.gradle.launcher.bootstrap.ProcessBootstrap 1 ['page74_issue7']
# org.gradle.wrapper.BootstrapMainStarter 1 ['page74_issue7']
# com.android.internal.os.ZygoteInit$MethodAndA rgsCaller 1 ['page146_issue4']
# ++++++++++++++++++++
# file: com.android.internal.os.ZygoteInit$MethodAndArgsCaller  connects
# ...
# org.mapsforge.map.layer.LayerManager 1 ['page25_issue24']
# ++++++++++++++++++++
# file: cgeo.geocaching.settings.AbstractCheckCredentialsPreference$LoginCheckClickListener  connects
# android.preference.Preference 1 ['page92_issue12']
# ++++++++++++++++++++
# file: cgeo.geocaching.EditWaypointActivity$1SaveWptTask  connects
# cgeo.geocaching.EditWaypointActivity$1SaveWptTask 1 ['page92_issue16']
# android.os.AsyncTask$2 1 ['page92_issue16']
# ++++++++++++++++++++
# file: cgeo.geocaching.apps.navi.MapsMeApp  connects
# cgeo.geocaching.apps.navi.MapsMeApp 1 ['page92_issue22']
# cgeo.geocaching.apps.navi.NavigationAppFactory 1 ['page92_issue22']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.NavigationActionProvider$1  connects
# android.view.View 1 ['page92_issue22']
# ++++++++++++++++++++
# file: java.lang.Object  connects
# java.lang.Thread 1 ['page110_issue7']
# java.lang.Object 42 ['page145_issue9']
# cgeo.geocaching.MainActivity$CountBubbleUpdateThread 42 ['page145_issue9']
# ++++++++++++++++++++
# file: sun.misc.Unsafe  connects
# java.util.concurrent.locks.LockSupport 1 ['page110_issue7']
# ++++++++++++++++++++
# file: java.util.concurrent.locks.LockSupport  connects
# java.util.concurrent.locks.AbstractQueuedSynchronizer 1 ['page110_issue7']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.DirectionImage  connects
# cgeo.geocaching.ui.CacheListAdapter 1 ['page110_issue7']
# ++++++++++++++++++++
# file: com.google.android.gms.internal.jm  connects
# com.google.android.gms.common.api.c 1 ['page110_issue8']
# com.google.android.gms.internal.jl$a 1 ['page110_issue8']
# ++++++++++++++++++++
# file: com.google.android.gms.common.api.c  connects
# com.google.android.gms.common.api.c 1 ['page110_issue8']
# com.google.android.gms.common.api.c$4 1 ['page110_issue8']
# ++++++++++++++++++++
# file: com.google.android.gms.common.api.c$4  connects
# com.google.android.gms.internal.jm 1 ['page110_issue8']
# ++++++++++++++++++++
# file: com.google.android.gms.internal.jl$a  connects
# android.os.Handler 1 ['page110_issue8']
# ++++++++++++++++++++
# file: cgeo.geocaching.sensors.GeoData  connects
# cgeo.geocaching.playservices.LocationProvider 1 ['page110_issue19']
# ++++++++++++++++++++
# file: cgeo.geocaching.sensors.Sensors  connects
# cgeo.geocaching.CgeoApplication 1 ['page110_issue19']
# ++++++++++++++++++++
# file: org.mapsforge.core.model.Tile  connects
# org.mapsforge.map.util.LayerUtil 5 ['page10_issue3']
# ++++++++++++++++++++
# file: org.mapsforge.map.util.LayerUtil  connects
# org.mapsforge.map.layer.TileLayer 5 ['page10_issue3']
# ++++++++++++++++++++
# file: org.mapsforge.map.layer.TileLayer  connects
# org.mapsforge.map.layer.LayerManager 5 ['page10_issue3']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.EditNoteDialog  connects
# cgeo.geocaching.ui.EditNoteDialog 1 ['page10_issue22']
# cgeo.geocaching.ui.-$$Lambda$EditNoteDialog$21Wqj5hcRhEKvTHNPBOthYPs7Cw 1 ['page10_issue22']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.-$$Lambda$EditNoteDialog$21Wqj5hcRhEKvTHNPBOthYPs7Cw  connects
# android.view.View 1 ['page10_issue22']
# ++++++++++++++++++++
# file: androidx.test.espresso.action.MotionEvents  connects
# androidx.test.espresso.action.Tap 1 ['page10_issue22']
# ++++++++++++++++++++
# file: androidx.test.espresso.action.Tap  connects
# androidx.test.espresso.action.Tap$1 1 ['page10_issue22']
# ++++++++++++++++++++
# file: cgeo.geocaching.MainActivity$CountBubbleUpdateThread  connects
# java.lang.Object 41 ['page145_issue9']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.AbstractCachingListViewPageViewCreator  connects
# cgeo.geocaching.activity.AbstractViewPagerActivity$ViewPagerAdapter 1 ['page145_issue17']
# ++++++++++++++++++++
# file: android.support.v4.view.ViewPager$PagerObserver  connects
# android.database.DataSetObservable 1 ['page145_issue17']
# ++++++++++++++++++++
# file: android.support.v4.view.PagerAdapter  connects
# cgeo.geocaching.activity.AbstractViewPagerActivity 1 ['page145_issue17']
# ++++++++++++++++++++
# file: cgeo.geocaching.log.LogTemplateProviderTest  connects
# java.lang.reflect.Method 1 ['page6_issue13']
# ++++++++++++++++++++
# file: cgeo.geocaching.models.ManualRoute  connects
# cgeo.geocaching.models.ManualRoute 2 ['page6_issue17']
# cgeo.geocaching.models.-$$Lambda$ManualRoute$Zq5RjiHZa1mXEdSSrXm2UAJEDJU 1 ['page6_issue17']
# ++++++++++++++++++++
# file: cgeo.geocaching.models.-$$Lambda$ManualRoute$Zq5RjiHZa1mXEdSSrXm2UAJEDJU  connects
# cgeo.geocaching.utils.AndroidRxUtils 1 ['page6_issue17']
# ++++++++++++++++++++
# file: cgeo.geocaching.settings.SettingsActivity$8  connects
# cgeo.geocaching.settings.SettingsActivity 2 ['page155_issue4', 'page155_issue8']
# ++++++++++++++++++++
# file: cgeo.geocaching.filter.DistanceFilter  connects
# cgeo.geocaching.filter.AbstractFilter 1 ['page155_issue7']
# ++++++++++++++++++++
# file: cgeo.geocaching.cgeocaches$12  connects
# cgeo.geocaching.cgeocaches$12 1 ['page155_issue7']
# cgeo.geocaching.filter.FilterUserInterface$3 1 ['page155_issue7']
# ++++++++++++++++++++
# file: cgeo.geocaching.filter.FilterUserInterface$3  connects
# com.android.internal.app.AlertController$AlertParams$3 1 ['page155_issue7']
# ++++++++++++++++++++
# file: com.android.internal.view.menu.ContextMenuBuilder  connects
# com.android.internal.policy.impl.PhoneWindow$DecorView 1 ['page87_issue1']
# ++++++++++++++++++++
# file: android.view.View$CheckForLongPress  connects
# android.os.Handler 1 ['page87_issue1']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.ec.ECLogin  connects
# cgeo.geocaching.connector.AbstractLogin 1 ['page87_issue15']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.AbstractLogin  connects
# cgeo.geocaching.connector.ec.ECConnector 1 ['page87_issue15']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.ec.ECConnector  connects
# cgeo.geocaching.MainActivity$4 1 ['page87_issue15']
# ++++++++++++++++++++
# file: cgeo.geocaching.MainActivity$4  connects
# rx.internal.schedulers.ScheduledAction 1 ['page87_issue15']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.gc.PocketQueryListActivity$1  connects
# cgeo.geocaching.connector.gc.PocketQueryListActivity$1 1 ['page87_issue16']
# rx.Observable$27 1 ['page87_issue16']
# ++++++++++++++++++++
# file: com.google.android.gms.location.internal.zzi$zza$1  connects
# android.os.Handler 1 ['page87_issue20']
# ++++++++++++++++++++
# file: cgeo.geocaching.utils.DatabaseBackupUtils$3  connects
# cgeo.geocaching.utils.DatabaseBackupUtils$3 1 ['page112_issue14']
# rx.util.async.operators.OperatorFromFunctionals$InvokeAsync 1 ['page112_issue14']
# ++++++++++++++++++++
# file: rx.util.async.operators.OperatorFromFunctionals$InvokeAsync  connects
# rx.util.async.operators.OperatorFromFunctionals$InvokeAsync 1 ['page112_issue14']
# rx.Observable 1 ['page112_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.maps.DirectionDrawer  connects
# cgeo.geocaching.maps.PositionAndScaleOverlay 3 ['page68_issue4', 'page68_issue5', 'page68_issue23']
# ++++++++++++++++++++
# file: cgeo.geocaching.maps.PositionAndScaleOverlay  connects
# cgeo.geocaching.maps.PositionAndScaleOverlay 4 ['page68_issue4', 'page68_issue5', 'page68_issue23', 'page101_issue14']
# cgeo.geocaching.maps.mapsforge.MapsforgeOverlay 4 ['page68_issue4', 'page68_issue5', 'page68_issue23', 'page101_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.maps.mapsforge.MapsforgeOverlay  connects
# org.mapsforge.v3.android.maps.overlay.Overlay 3 ['page68_issue4', 'page68_issue5', 'page68_issue23']
# org.mapsforge.android.maps.overlay.Overlay 1 ['page101_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.utils.CanvasUtils  connects
# cgeo.geocaching.maps.DirectionDrawer 1 ['page68_issue5']
# ++++++++++++++++++++
# file: cgeo.geocaching.NavigateAnyPointActivity$CoordDialogListener  connects
# android.view.View 1 ['page136_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.maps.CGeoMap$2  connects
# cgeo.geocaching.maps.CGeoMap$2 1 ['page90_issue10']
# android.os.AsyncTask$2 1 ['page90_issue10']
# ++++++++++++++++++++
# file: cgeo.geocaching.cgGeo  connects
# cgeo.geocaching.cgGeo 2 ['page232_issue15']
# cgeo.geocaching.cgGeo$cgeoGpsStatusListener 1 ['page232_issue15']
# ++++++++++++++++++++
# file: cgeo.geocaching.cgGeo$cgeoGpsStatusListener  connects
# android.location.LocationManager$GpsStatusListenerTransport$1 1 ['page232_issue15']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.oc.OCApiConnector$1  connects
# cgeo.geocaching.connector.oc.OCApiConnector$1 1 ['page77_issue18']
# rx.internal.operators.OnSubscribeDefer 1 ['page77_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.maps.mapsforge.MapsforgeMapProvider$OfflineMapSource  connects
# cgeo.geocaching.maps.CGeoMap 1 ['page15_issue3']
# ++++++++++++++++++++
# file: android.widget.AbsListView$7  connects
# android.os.Handler 2 ['page15_issue3', 'page29_issue23']
# ++++++++++++++++++++
# file: junit.runner.BaseTestRunner  connects
# junit.textui.TestRunner 1 ['page15_issue21']
# ++++++++++++++++++++
# file: junit.textui.TestRunner  connects
# junit.textui.TestRunner 2 ['page15_issue21']
# com.intellij.rt.junit.JUnitStarter 1 ['page15_issue21']
# ++++++++++++++++++++
# file: com.intellij.rt.junit.JUnitStarter  connects
# com.intellij.rt.junit.JUnitStarter 2 ['page15_issue21']
# ++++++++++++++++++++
# file: cgeo.geocaching.LogCacheActivity$PostListener  connects
# android.view.View 1 ['page154_issue23']
# ++++++++++++++++++++
# file: java.io.BufferedOutputStream  connects
# java.io.BufferedOutputStream 1 ['page167_issue25']
# java.io.OutputStreamWriter 1 ['page167_issue25']
# ++++++++++++++++++++
# file: java.io.OutputStreamWriter  connects
# java.io.OutputStreamWriter 1 ['page167_issue25']
# android.support.v4.app.ActivityCompatHoneycomb 1 ['page167_issue25']
# ++++++++++++++++++++
# file: cgeo.geocaching.export.FieldnoteExport$ExportTask  connects
# cgeo.geocaching.export.FieldnoteExport$ExportTask 1 ['page167_issue25']
# cgeo.geocaching.utils.AsyncTaskWithProgress 1 ['page167_issue25']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.dialog.CoordinatesCalculateDialog  connects
# cgeo.geocaching.ui.dialog.CoordinatesCalculateDialog 2 ['page55_issue18']
# cgeo.geocaching.ui.EditButton 1 ['page55_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.EditButton  connects
# cgeo.geocaching.ui.CalculateButton 1 ['page55_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.CalculateButton  connects
# cgeo.geocaching.ui.CalculateButton$CoordDigitClickListener 1 ['page55_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.CalculateButton$CoordDigitClickListener  connects
# android.view.View 1 ['page55_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.speech.SpeechService  connects
# android.app.ActivityThread 1 ['page137_issue17']
# ++++++++++++++++++++
# file: java.util.HashMap  connects
# java.util.HashSet 1 ['page137_issue18']
# ++++++++++++++++++++
# file: java.util.HashSet  connects
# cgeo.geocaching.DataStore 1 ['page137_issue18']
# ++++++++++++++++++++
# file: cgeo.geocaching.connector.ConnectorFactory$2$1  connects
# cgeo.geocaching.connector.ConnectorFactory$2$1 1 ['page137_issue22']
# rx.operators.OperatorMap$1 1 ['page137_issue22']
# ++++++++++++++++++++
# file: rx.Notification  connects
# rx.subjects.PublishSubject$2 1 ['page137_issue23']
# ++++++++++++++++++++
# file: rx.subjects.PublishSubject$2  connects
# rx.subjects.PublishSubject$2 1 ['page137_issue23']
# rx.subjects.SubjectSubscriptionManager$1 1 ['page137_issue23']
# ++++++++++++++++++++
# file: rx.operators.OperationMulticast$MulticastConnectableObservable$1  connects
# rx.operators.OperationMulticast$MulticastConnectableObservable$1 1 ['page137_issue23']
# rx.Observable 1 ['page137_issue23']
# ++++++++++++++++++++
# file: rx.operators.OperationRefCount$RefCount  connects
# rx.Observable$1 1 ['page137_issue23']
# ++++++++++++++++++++
# file: cgeo.geocaching.CacheListActivity$LoadDetailsThread  connects
# cgeo.geocaching.CacheListActivity$LoadDetailsThread 1 ['page137_issue23']
# ++++++++++++++++++++
# file: cgeo.geocaching.DataStore$4  connects
# java.lang.Thread 1 ['page137_issue24']
# ++++++++++++++++++++
# file: cgeo.geocaching.googlemaps.googleMapView  connects
# android.view.View 1 ['page231_issue18']
# ++++++++++++++++++++
# file: java.util.ArrayList$Itr  connects
# org.assertj.core.presentation.StandardRepresentation 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.presentation.StandardRepresentation  connects
# org.assertj.core.presentation.StandardRepresentation 3 ['page57_issue11']
# org.assertj.core.error.MessageFormatter 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.error.MessageFormatter  connects
# org.assertj.core.error.MessageFormatter 2 ['page57_issue11']
# org.assertj.core.error.BasicErrorMessageFactory 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.error.BasicErrorMessageFactory  connects
# org.assertj.core.internal.Failures 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.internal.Failures  connects
# org.assertj.core.internal.CommonValidations 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.internal.CommonValidations  connects
# org.assertj.core.internal.Iterables 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.internal.Iterables  connects
# org.assertj.core.api.AbstractIterableAssert 1 ['page57_issue11']
# ++++++++++++++++++++
# file: org.assertj.core.api.AbstractIterableAssert  connects
# cgeo.geocaching.files.GPXImporterTest 1 ['page57_issue11']
# ++++++++++++++++++++
# file: cgeo.geocaching.files.GPXImporterTest  connects
# java.lang.reflect.Method 1 ['page57_issue11']
# ++++++++++++++++++++
# file: cgeo.geocaching.settings.SettingsActivity$10  connects
# android.preference.Preference 1 ['page130_issue10']
# ++++++++++++++++++++
# file: android.preference.EditTextPreference  connects
# android.preference.DialogPreference 1 ['page130_issue10']
# ++++++++++++++++++++
# file: cgeo.geocaching.utils.LogTemplateProvider$5  connects
# cgeo.geocaching.utils.LogTemplateProvider$LogTemplate 1 ['page130_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.utils.LogTemplateProvider$LogTemplate  connects
# cgeo.geocaching.utils.LogTemplateProvider 1 ['page130_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.utils.LogTemplateProvider  connects
# cgeo.geocaching.LogCacheActivity 1 ['page130_issue14']
# ++++++++++++++++++++
# file: cgeo.geocaching.ui.ImagesList$AsyncImgLoader  connects
# cgeo.geocaching.ui.ImagesList$AsyncImgLoader 1 ['page156_issue20']
# android.os.AsyncTask$2 1 ['page156_issue20']
# ++++++++++++++++++++
# file: cgeo.geocaching.VisitCacheActivity  connects
# cgeo.geocaching.VisitCacheActivity 1 ['page173_issue21']
# android.support.v4.app.LoaderManagerImpl$LoaderInfo 1 ['page173_issue21']
# ++++++++++++++++++++
# file: android_maps_conflict_avoidance.com.google.googlenav.map.BaseTileRequest  connects
# android_maps_conflict_avoidance.com.google.googlenav.map.MapService$MapTileRequest 1 ['page89_issue6']
# ++++++++++++++++++++
# file: android_maps_conflict_avoidance.com.google.googlenav.map.MapService$MapTileRequest  connects
# android_maps_conflict_avoidance.com.google.googlenav.datarequest.DataRequestDispatcher 1 ['page89_issue6']
# ++++++++++++++++++++
# file: android_maps_conflict_avoidance.com.google.googlenav.datarequest.DataRequestDispatcher  connects
# android_maps_conflict_avoidance.com.google.googlenav.datarequest.DataRequestDispatcher 1 ['page89_issue6']
# android_maps_conflict_avoidance.com.google.googlenav.datarequest.DataRequestDispatcher$DispatcherServer 1 ['page89_issue6']
# ++++++++++++++++++++
# file: android_maps_conflict_avoidance.com.google.googlenav.datarequest.DataRequestDispatcher$DispatcherServer  connects
# java.lang.Thread 1 ['page89_issue6']
# ++++++++++++++++++++
# file: cgeo.geocaching.apps.cachelist.MapsWithMeCacheListApp  connects
# cgeo.geocaching.CacheListActivity$10 1 ['page101_issue20']
# ++++++++++++++++++++
# file: cgeo.geocaching.CacheListActivity$10  connects
# cgeo.geocaching.apps.cachelist.ListNavigationSelectionActionProvider$1 1 ['page101_issue20']
# ++++++++++++++++++++
# file: cgeo.geocaching.apps.cachelist.ListNavigationSelectionActionProvider$1  connects
# android.support.v7.internal.view.menu.MenuItemWrapperICS$OnMenuItemClickListenerWrapper 1 ['page101_issue20']
# ++++++++++++++++++++
# file: cgeo.geocaching.settings.SettingsActivity$1  connects
# android.preference.Preference 1 ['page122_issue23']
# ++++++++++++++++++++

# %%
# find stack traces per category
# additional label None used for issues which have stack trace but they dont have any tag.

tags_freq_dict = dict()
tags_freq_dict["None"] = 0
for tags in tags_list:
    if tags == []:
        tags_freq_dict["None"] += 1
    else:
        for tag in tags:
            if tag in tags_freq_dict:
                tags_freq_dict[tag] += 1
            else:
                tags_freq_dict[tag]  = 1

# %%
print(tags_freq_dict)
# Out:
# {'None': 50, 'Bug': 414, 'Regression': 32, 'Connector OC': 7, 'Google Play or Beta feedback': 163, 'Prio - Medium': 19, "Won't Fix": 13, 'Prio - High': 85, 'Refactoring': 5, 'Website': 2, 'CI server / Build tools': 15, 'Unverified': 56, 'Duplicate': 14, 'Assigned-non-collab': 5, 'Prio - Low': 17, 'Live Map': 9, 'Feedback required': 5, 'Map: Mapsforge': 13, 'Regression SDK30/SAF': 5, 'Regression SDK26': 7, 'Connector GK': 4, 'Connector LC': 1, 'Feature Request': 2, 'Connector EC': 1, 'WP Calc': 3, 'Field test': 5, 'Map: GMapsV2': 1, 'Frontend Design': 1}
