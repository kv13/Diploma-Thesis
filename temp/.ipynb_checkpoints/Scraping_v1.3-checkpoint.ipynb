# %% [markdown]
# # Github Repo Scraper

# %%
#import libraries
import os
import re
import bs4
import csv
import time
import requests
import json, codecs
from pprint import pprint
from github import Github
from bs4 import BeautifulSoup

# %%
#write results on a file in json format
def write_json(page_objects,page):
    
    path_name = '../data1'
    if not os.path.exists(path_name):
        os.makedirs(path_name)
    
    file = 'open_data_word_emb' + str(page) + '.json'
    
    with open(os.path.join(path_name,file),'a') as f:
        json.dump(page_objects,f)

# %%
#define functions 
def find_tags(tags,each_issue):
    for counter,temp in enumerate(each.find_all('a')):
        tag = str(temp.string)
        if tag != "None":
            tags.append(tag)
        
    remove_special_ch(tags)

# %%
#maybe embody it in the find_desc function to reduce iterations.
def remove_special_ch(text):
    
    for i in range(0,len(text)):
        text[i] = text[i].replace('\n',' ')
        text[i] = text[i].replace('\t',' ')
        text[i] = re.sub(r"<.*?>"," ",text[i])
        #maybe better solution is <[^<>]+> matches any character except < or > 
        #one or more times included inside < and >

# %%
def search_all_page(stack_trace,page):
    temp = page.find_all('div',class_='edit-comment-hide')
    for i in temp:
        temp_2 = i.find('td')
        temp_desc = []
        calculate_desc(temp_2,temp_desc,stack_trace,0)
        if stack_trace != []:
            break

# %%
def find_desc(each,base_url,description,stack_trace,is_bug):
    
    next_url     = base_url+each.find('a')['href']
    response     = requests.get(next_url)
    html_content = response.content
    dom          = BeautifulSoup(html_content,'html.parser')
    temp         = dom.find('div',class_ = 'edit-comment-hide')
    temp_2       = temp.find('td')
    
    #find description and the stack trace
    calculate_desc(temp_2,description,stack_trace,1)
    
    #search all the page for a stack trace
    if stack_trace == [] and is_bug == 1:
        search_all_page(stack_trace,dom)
    
    #find the person who closed the issue
    who_closed_it = "none"
    temp_3        = dom.find_all('div',class_='TimelineItem-body') 
    for i in temp_3:
        if i.text.find('closed this')!=-1:
            if i.find('a',class_='author Link--primary text-bold') is None:
                continue
            who_closed_it = i.find('a',class_='author Link--primary text-bold').text
    
    #remove special characters from the description and stack trace
    remove_special_ch(description)
    
    if stack_trace != []:
        remove_special_ch(stack_trace)
    
    return who_closed_it

# %%
def calculate_desc(html_text,description,stack_trace,flag):
    
    html_content = html_text.contents
    length = len(html_content)
    
    if length == 1:
        #some lines are empty. No need to write them
        if html_content[0]!= []:
            str_temp = str(html_content[0])
            if str_temp.find('.java:')!=-1 or str_temp.find('java.')!=-1 or str_temp.find('AndroidRuntime:')!=-1:
                stack_trace.append(str(html_content[0]))
            else:
                if flag == 1:
                    if str(html_content[0]).startswith('<code>') != True:
                        description.append(str(html_content[0]))
    else:
        for i in range(length):
            
            if type(html_content[i]) is bs4.element.NavigableString:
                #avoid writting empty lines and html tags <br>
                if len(html_content[i])>4:
                        str_temp = str(html_content[i])
                        if str_temp.find('.java:')!=-1 or str_temp.find('java.')!=-1 or str_temp.find('AndroidRuntime:')!=-1:
                            stack_trace.append(str(html_content[i]))
                        elif flag == 1:
                            description.append(str(html_content[i]))
            elif type(html_content[i] is bs4.element.Tag):
                #call recursively the function till length is 1
                calculate_desc(html_content[i],description,stack_trace,flag)

# %%
#search all closed issues

#define some variables
total_issues  = 0
total_traces  = 0
total_bugs    = 0
pages_counter = 0
issues        = []


#initialize important url's
base_url = "https://github.com/"
#query_url = f"https://github.com/cgeo/cgeo/issues?page=1&q=is%3Aissue+is%3Aclosed"
query_url = f"https://github.com/cgeo/cgeo/issues?page=1&q=is%3Aissue+is%3Aopen"

#authorization in order to make more requests.
token = os.getenv("GITHUB_TOKEN")
headers = {'Authorization': f'token {token}'}

response = requests.get(query_url, headers = headers)

# %%
#loop through all pages

while True:
    response_code = response.status_code
    
    if response_code != 200:
        raise Exception("Error Occured")
    else:
        html_content = response.content
        dom = BeautifulSoup(html_content,'html.parser')
        
        #find all issues in every page
        all = dom.findAll('div', class_='flex-auto min-width-0 p-2 pr-3 pr-md-2')
        
        page_objects = []
        pages_counter += 1
        
        #real scraping begins
        #search all issues per page
        for each in all:
            
            #find tags and who open the issue
            tags=[]
            find_tags(tags,each)
            
            #flag that is activated if the issue is bug
            is_bug = 0
            for i in tags:
                if i == "Bug":
                    is_bug = 1
                    total_bugs = total_bugs+1
            
            #find description, stack trace and who closed
            description   = []
            stack_trace   = []
            who_closed_it = find_desc(each,base_url,description,stack_trace,is_bug)
            
            total_issues = total_issues+1
            if stack_trace !=[]:
                total_traces = total_traces +1
            
            print(total_issues,tags[0])
            
            #write dictionary
            if len(tags)>=1:
                issue_object = {'name':tags[0],'tags':tags[1:-1],'opened_by':tags[len(tags)-1],
                                'description':description,'stack_trace':stack_trace,'closed_by':who_closed_it}
            
            
            page_objects.append(issue_object)
        
        #write issues by page 
        write_json(page_objects,pages_counter)
        
        #combine all issues to a global list
        #issues.extend(page_objects)
        
        #visit the next page if exists
        end = dom.findAll('a',class_='next_page')
        if end == []:
            break
        
        next_url = base_url + end[1]['href']
        response = requests.get(next_url)
        
        ##for debugging
        if total_issues % 25 != 0:
            print("##########################\nTHE PAGE##############\n ",pages_counter,"HAS NOT 25 ISSUES",)
        ##
        
        # Sleep for 60 seconds
        time.sleep(60)
# Out:
# 1 Test issue with new issue forms
# 2 Migration of global hide settings into live filter
# 3 Log summary only updated after re-entering cache
# 4 Text field hint not properly aligned
# 5 Geocode input in LogTrackable Activity uses wrong style
# 6 Found OC caches not shown as found in search results
# 7 Make actiobar bg color a bit darker again
# 8 Map doesn't support vector drawables for markers
# 9 GCVote seems missing in our new search?
# 10 Modified coords not recognized on updating/downloading cache data
# 11 Next bugfix release
# 12 ExceptionInInitializerError / java.lang.IllegalArgumentException
# 13 Store regExpr to fetch data from web-site into an own "service" to avoid the necessity of a release if changes happen
# 14 Cache notes not available
# 15 system information - "Hide caches" bad formatting
# 16 Filter: Allow direct date input (in addition to date picker)
# 17 Make actionbar font size fixed
# 18 Nightly build failed with exception
# 19 [New Filter] Filtering for "FOUND=NO" gives unexpected result
# 20 Archived caches - difference between connectors
# 21 NPE in TabbedViewPager
# 22 Unwanted folder duplication within base folder
# 23 Show on map -> Locus no longer available
# 24 List spinner cut off with large fonts
# 25 filter "saved since" to '-' does not work
# 26 number of filtered caches not refreshed, when count=0
# 27 list limit - set correct possition after load next entries
# 28 Enhance system info by filter information
# 29 Filter status does not scale favorite percentages
# 30 Filter Button on Main Screen is inoperable
# 31 Amount of waypoints not visible in tab title from description tab any more
# 32 Lists: Increase font brightness and contrast for Favo count in Rating field
# 33 Use darker accent color for white theme?
# 34 Friend Log Page Setting doesn't work
# 35 Include version in topic of problem report
# 36 choose different color for cache log details
# 37 Replace or remove redundant geoode in map popup
# 38 Show user understandable filter info for fav percentage
# 39 Favorite percentage filter not meaningful for live map
# 40 System information has bad contrast
# 41 Specific search returns all caches from oc.nl
# 42 Navigation target selection broken
# 43 Fav count has wrong color in dark mode
# 44 Crash when attempting to open a cache from a link.
# 45 Chrome Webview not avalable
# 46 maps.me navigation not available
# 47 Remove the 1000 caches limit from lists
# 48 Font size feedbacks
# 49 Selection box "NEIN" in status filter is cut off
# 50 Missing Background Image
# 51 Filter-dialog: icon for "own vote" nearly invisible in dark mode
# 52 map label font too large, cuts off
# 53 First start after update shows "Version/help", not "Changelog"
# 54 Crash when attempting to open cache details
# 55 Waypoint name don't shown up at all
# 56 New Filter Framework: remove "Found by" search?
# 57 settings dialogs broken in dark theme
# 58 replace global cache type filter with a temporary info popup
# 59 set map language not remember
# 60 Remove "Remove list" question dialog
# 61 Radar no longer available as navigation method
# 62 Icons of linked apps are black/white only
# 63 Trackable text is grey
# 64 Trackable image gets duplicated
# 65 Optimize "icon buttons"
# 66 [Nightly] Rating Stars' colors hard to distinguish
# 67 Use same icons in filter and quick settings
# 68 [Nightly] Filter (new) does not hide waypoints
# 69 Overflow menu use wrong background color in light mode
# 70 Differentiate between locked and archived states
# 71 Four digit favorite points truncated in list view
# 72 Also show action bar item text for "Show on map"
# 73 All lists except history lose their position
# 74 [Nightly] Personal Note - poss. not recognized as normal text input window?
# 75 [Nightly] Edit signature: weird text coverings (dark theme)
# 76 Optimize popup title bar
# 77 Evaluate using a different action bar color
# 78 Multi textinput style inconsistent
# 79 Personal note dialog action items not visible in light theme
# 80 Altitude lines in offline maps
# 81 Cache + WP icons of found caches do not show up in GM/Sat (if filtered)
# 82 [Nightly] Edit signature: Cursor invisible (dark theme)
# 83 Material Theming: List of Lists needs reformatting
# 84 Open cache with last active tab not working for logbook
# 85 Images vanishing from cache image tab
# 86 Live Map - "Center position" - click sensitive area too small
# 87 List of caches always jumps to first entry after returning from an opened cache
# 88 Logbook always jumps back to first log after changing pages
# 89 WP type dropdown selector looks strange
# 90 why is only one build instance active?
# 91 Tapping outside PN edit windows discards changes
# 92 D/T stars no longer red after swiping through a cache
# 93 Image select activity: Refactor buttons
# 94 Add setting: radio buttons vanishing
# 95 New filter: removing old cache list filter: what is left to do before this step?
# 96 New Filter: remove Global filters "exclude own/found, disabled. Archived",
# 97 Emojis in emoji selector are way too small
# 98 Adding/Removing from watchlist not working
# 99 Geocaching.com: watchlist counter no longer valid (always returns 2)
# 100 Crash when trying to change cache description of UDC's
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c38041aedc37> in <module>
#      70
#      71         # Sleep for 60 seconds
# ---> 72         time.sleep(60)
#
# KeyboardInterrupt:

# %%
#print some statistics
print(total_bugs)
print(total_traces)
print(total_issues)

# %%
# to ask
# make small changes and code that is not stack trace i discard it. Is it ok??
